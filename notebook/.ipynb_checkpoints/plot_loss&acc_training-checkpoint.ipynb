# %%
import csv
from collections import namedtuple
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
model="new_models"

# !tree ../new_models/
# Out:
# ../new_models/
# ├── GoogLeNet_PETA
# │   ├── binary61_epoch100_valloss0.10.hdf5
# │   ├── binary61_epoch50_valloss0.17.hdf5
# │   ├── binary61_final_model.h5
# │   └── binary61_log.csv
# ├── GoogLeNetSPP_PETA
# │   ├── binary61_epoch100_valloss0.24.hdf5
# │   ├── binary61_epoch50_valloss0.25.hdf5
# │   ├── binary61_final_model.h5
# │   └── binary61_log.csv
# ├── hiarBayesGoogLeNet_PETA
# │   ├── binary61_multi_epoch100_valloss0.09.hdf5
# │   ├── binary61_multi_epoch50_valloss0.14.hdf5
# │   ├── binary61_multi_final_model.h5
# │   └── binary61_multi_log.csv
# ├── hiarGoogLeNet_PETA
# │   ├── binary61_epoch100_valloss0.09.hdf5
# │   ├── binary61_epoch50_valloss0.17.hdf5
# │   ├── binary61_final_model.h5
# │   └── binary61_log.csv
# ├── hiarGoogLeNetSPP_PETA
# │   ├── binary61_epoch100_valloss0.13.hdf5
# │   ├── binary61_epoch50_valloss0.22.hdf5
# │   ├── binary61_final_model.h5
# │   └── binary61_log.csv
# └── hiarGoogLeNetWAM_PETA
#     ├── binary61_epoch100_valloss0.14.hdf5
# ...

# %%
log_dir = '../'+model+'/GoogLeNetSPP_PETA/'
loss_GoogLeNetSPP = []
acc_GoogLeNetSPP = []
val_loss_GoogLeNetSPP = []
val_acc_GoogLeNetSPP = []

with open(log_dir + 'binary61_log.csv', newline='') as csvfile:
    """
    spamreader = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in spamreader:
        print(','.join(row))#str type
        #print(row)#str type
    """
    """
    f_csv = csv.reader(csvfile)
    headings = next(f_csv)
    Row = namedtuple('Row', headings)
    for r in f_csv:
        row = Row(*r)
        print(row.loss)
        print(type(row.loss))#<class 'str'>
    """
    f_csv = csv.DictReader(csvfile)
    for row in f_csv:
        #print(type(row['loss']))#<class 'str'>
        loss_GoogLeNetSPP.append(float(row['loss']))
        acc_GoogLeNetSPP.append(float(row['acc']))
        val_loss_GoogLeNetSPP.append(float(row['val_loss']))
        val_acc_GoogLeNetSPP.append(float(row['val_acc']))
        
print(np.shape(loss_GoogLeNetSPP))
# Out:
# (100,)

# %%
log_dir = '../'+model+'/hiarGoogLeNetSPP_PETA/'
loss_hiarGoogLeNetSPP = []
acc_hiarGoogLeNetSPP = []
val_loss_hiarGoogLeNetSPP = []
val_acc_hiarGoogLeNetSPP = []

with open(log_dir + 'binary61_log.csv', newline='') as csvfile:
    f_csv = csv.DictReader(csvfile)
    for row in f_csv:
        #print(type(row['loss']))#<class 'str'>
        loss_hiarGoogLeNetSPP.append(float(row['loss']))
        acc_hiarGoogLeNetSPP.append(float(row['acc']))
        val_loss_hiarGoogLeNetSPP.append(float(row['val_loss']))
        val_acc_hiarGoogLeNetSPP.append(float(row['val_acc']))
        
print(np.shape(loss_hiarGoogLeNetSPP))
# Out:
# (100,)

# %%
log_dir = '../'+model+'/GoogLeNet_PETA/'
loss_GoogLeNet = []
acc_GoogLeNet = []
val_loss_GoogLeNet = []
val_acc_GoogLeNet = []

with open(log_dir + 'binary61_log.csv', newline='') as csvfile:
    f_csv = csv.DictReader(csvfile)
    for row in f_csv:
        #print(type(row['loss']))#<class 'str'>
        loss_GoogLeNet.append(float(row['loss']))
        acc_GoogLeNet.append(float(row['acc']))
        val_loss_GoogLeNet.append(float(row['val_loss']))
        val_acc_GoogLeNet.append(float(row['val_acc']))
        
print(np.shape(loss_GoogLeNet))
# Out:
# (100,)

# %%
log_dir = '../'+model+'/hiarGoogLeNet_PETA/'
loss_hiarGoogLeNet = []
acc_hiarGoogLeNet = []
val_loss_hiarGoogLeNet = []
val_acc_hiarGoogLeNet = []

with open(log_dir + 'binary61_log.csv', newline='') as csvfile:
    f_csv = csv.DictReader(csvfile)
    for row in f_csv:
        #print(type(row['loss']))#<class 'str'>
        loss_hiarGoogLeNet.append(float(row['loss']))
        acc_hiarGoogLeNet.append(float(row['acc']))
        val_loss_hiarGoogLeNet.append(float(row['val_loss']))
        val_acc_hiarGoogLeNet.append(float(row['val_acc']))
        
print(np.shape(loss_hiarGoogLeNet))
# Out:
# (100,)

# %%
log_dir = '../'+model+'/hiarBayesGoogLeNet_PETA/'
loss_hiarBayesGoogLeNet = []
acc_hiarBayesGoogLeNet = []
val_loss_hiarBayesGoogLeNet = []
val_acc_hiarBayesGoogLeNet = []

with open(log_dir + 'binary61_multi_log.csv', newline='') as csvfile:
    f_csv = csv.DictReader(csvfile)
    for row in f_csv:
        #print(type(row['loss']))#<class 'str'>
        loss_hiarBayesGoogLeNet.append(float(row['loss']))
        acc_hiarBayesGoogLeNet.append(float(row['acc']))
        val_loss_hiarBayesGoogLeNet.append(float(row['val_loss']))
        val_acc_hiarBayesGoogLeNet.append(float(row['val_acc']))
        
print(np.shape(loss_hiarBayesGoogLeNet))
# Out:
# (100,)

# %%
log_dir = '../'+model+'/hiarGoogLeNetWAM_PETA/'
loss_hiarGoogLeNetWAM = []
acc_hiarGoogLeNetWAM = []
val_loss_hiarGoogLeNetWAM = []
val_acc_hiarGoogLeNetWAM = []

with open(log_dir + 'binary61_log.csv', newline='') as csvfile:
    f_csv = csv.DictReader(csvfile)
    for row in f_csv:
        #print(type(row['loss']))#<class 'str'>
        loss_hiarGoogLeNetWAM.append(float(row['loss']))
        acc_hiarGoogLeNetWAM.append(float(row['acc']))
        val_loss_hiarGoogLeNetWAM.append(float(row['val_loss']))
        val_acc_hiarGoogLeNetWAM.append(float(row['val_acc']))
        
print(np.shape(loss_hiarGoogLeNetWAM))
# Out:
# (100,)

# %%
"""
plt.subplot(221)
plt.plot(loss, color='red', marker='x', linestyle='-', linewidth=1, markersize=0.1)
plt.xlabel("epoches")
plt.ylabel("loss")
plt.subplot(222)
plt.plot(acc, color='green', marker='x', linestyle='-', linewidth=1, markersize=0.1)
plt.xlabel("epoches")
plt.ylabel("accuracy")
plt.subplot(223)
plt.plot(val_loss, color='blue', marker='x', linestyle='-', linewidth=1, markersize=0.1)
plt.xlabel("epoches")
plt.ylabel("val_loss")
plt.subplot(224)
plt.plot(val_acc, color='yellow', marker='x', linestyle='-', linewidth=1, markersize=0.1)
plt.xlabel("epoches")
plt.ylabel("val_accuracy")
plt.subplots_adjust(top=0.92, bottom=0.08, left=0.10, right=0.95, hspace=0.5, wspace=0.5)
plt.show()
"""
fig = plt.figure(1)
fig.subplots_adjust(top=0.92, bottom=0.08, left=0.05, right=0.95, hspace=0.5, wspace=0.5)
ax_loss = fig.add_subplot(221)
ax_loss.set_xlabel("epoches")
ax_loss.set_ylabel("loss")
ax_loss.plot(loss_GoogLeNetSPP, color='red', marker='x', linestyle='-', linewidth=1, markersize=0.1)
ax_loss.plot(loss_hiarGoogLeNetSPP, color='blue', marker='x', linestyle='-', linewidth=1, markersize=0.1)
ax_loss.plot(loss_GoogLeNet, color='green', marker='x', linestyle='-', linewidth=1, markersize=0.1)
ax_loss.plot(loss_hiarGoogLeNet, color='black', marker='x', linestyle='-', linewidth=1, markersize=0.1)
ax_loss.plot(loss_hiarBayesGoogLeNet, color='cyan', marker='x', linestyle='-', linewidth=1, markersize=0.1)
ax_loss.plot(loss_hiarGoogLeNetWAM, color='magenta', marker='x', linestyle='-', linewidth=1, markersize=0.1)

ax_acc = fig.add_subplot(222)
ax_acc.set_xlabel("epoches")
ax_acc.set_ylabel("accuracy")
ax_acc.set_ylim(0.75, 1)
ax_acc.plot(acc_GoogLeNetSPP, color='red', marker='x', linestyle='-', linewidth=1, markersize=0.1)
ax_acc.plot(acc_hiarGoogLeNetSPP, color='blue', marker='x', linestyle='-', linewidth=1, markersize=0.1)
ax_acc.plot(acc_GoogLeNet, color='green', marker='x', linestyle='-', linewidth=1, markersize=0.1)
ax_acc.plot(acc_hiarGoogLeNet, color='black', marker='x', linestyle='-', linewidth=1, markersize=0.1)
ax_acc.plot(acc_hiarBayesGoogLeNet, color='cyan', marker='x', linestyle='-', linewidth=1, markersize=0.1)
ax_acc.plot(acc_hiarGoogLeNetWAM, color='magenta', marker='x', linestyle='-', linewidth=1, markersize=0.1)

ax_valloss = fig.add_subplot(223)
ax_valloss.set_xlabel("epoches")
ax_valloss.set_ylabel("val_loss")
ax_valloss.plot(val_loss_GoogLeNetSPP, color='red', marker='x', linestyle='-', linewidth=1, markersize=0.1)
ax_valloss.plot(val_loss_hiarGoogLeNetSPP, color='blue', marker='x', linestyle='-', linewidth=1, markersize=0.1)
ax_valloss.plot(val_loss_GoogLeNet,color='green', marker='x', linestyle='-', linewidth=1, markersize=0.1)
ax_valloss.plot(val_loss_hiarGoogLeNet, color='black', marker='x', linestyle='-', linewidth=1, markersize=0.1)
ax_valloss.plot(val_loss_hiarBayesGoogLeNet, color='cyan', marker='x', linestyle='-', linewidth=1, markersize=0.1)
ax_valloss.plot(val_loss_hiarGoogLeNetWAM, color='magenta', marker='x', linestyle='-', linewidth=1, markersize=0.1)

ax_valacc = fig.add_subplot(224)
ax_valacc.set_xlabel("epoches")
ax_valacc.set_ylabel("val_accuracy")
ax_valacc.set_ylim(0.80, 1)
ax_valacc.plot(val_acc_GoogLeNetSPP, color='red', marker='x', linestyle='-', linewidth=1, markersize=0.1)
ax_valacc.plot(val_acc_hiarGoogLeNetSPP, color='blue', marker='x', linestyle='-', linewidth=1, markersize=0.1)
ax_valacc.plot(val_acc_GoogLeNet, color='green', marker='x', linestyle='-', linewidth=1, markersize=0.1)
ax_valacc.plot(val_acc_hiarGoogLeNet, color='black', marker='x', linestyle='-', linewidth=1, markersize=0.1)
ax_valacc.plot(val_acc_hiarBayesGoogLeNet, color='cyan', marker='x', linestyle='-', linewidth=1, markersize=0.1)
ax_valacc.plot(val_acc_hiarGoogLeNetWAM, color='magenta', marker='x', linestyle='-', linewidth=1, markersize=0.1)

labels = ('GoogLeNetSPP', 'hiarGoogLeNetSPP', 'GoogLeNet', 'hiarGoogLeNet', 'hiarBayesGoogLeNet', 'hiarGoogLeNetWAM')
ax_valacc.legend(labels, loc='upper center', ncol=2, bbox_to_anchor= (-.3, -.5))#, borderaxespad=0, frameon=False, shadow=True
plt.show()
fig.savefig("../results/"+model+"_log.png", dpi=256, bbox_inches="tight")

# %%
log_dir = '../models/hiarBayesGoogLeNet_PETA/'
loss_con = []
acc_con = []
val_loss_con = []
val_acc_con = []

with open(log_dir + 'binary61_levelup_log.csv', newline='') as csvfile:
    f_csv = csv.DictReader(csvfile)
    for row in f_csv:
        #print(type(row['loss']))#<class 'str'>
        loss_con.append(float(row['loss']))
        acc_con.append(float(row['acc']))
        val_loss_con.append(float(row['val_loss']))
        val_acc_con.append(float(row['val_acc']))
        
print(np.shape(loss_con))

loss_add = []
acc_add = []
val_loss_add = []
val_acc_add = []

with open(log_dir + 'binary61_orig_log.csv', newline='') as csvfile:
    f_csv = csv.DictReader(csvfile)
    for row in f_csv:
        #print(type(row['loss']))#<class 'str'>
        loss_add.append(float(row['loss']))
        acc_add.append(float(row['acc']))
        val_loss_add.append(float(row['val_loss']))
        val_acc_add.append(float(row['val_acc']))
        
print(np.shape(loss_add))

loss_multi = []
acc_multi = []
val_loss_multi = []
val_acc_multi = []

with open(log_dir + 'binary61_multi_log.csv', newline='') as csvfile:
    f_csv = csv.DictReader(csvfile)
    for row in f_csv:
        #print(type(row['loss']))#<class 'str'>
        loss_multi.append(float(row['loss']))
        acc_multi.append(float(row['acc']))
        val_loss_multi.append(float(row['val_loss']))
        val_acc_multi.append(float(row['val_acc']))
        
print(np.shape(loss_multi))

loss_multi_loss1 = []
acc_multi_loss1 = []
val_loss_multi_loss1 = []
val_acc_multi_loss1 = []

with open(log_dir + 'binary61_multi_loss_log.csv', newline='') as csvfile:
    f_csv = csv.DictReader(csvfile)
    for row in f_csv:
        #print(type(row['loss']))#<class 'str'>
        loss_multi_loss1.append(float(row['loss']))
        acc_multi_loss1.append(float(row['acc']))
        val_loss_multi_loss1.append(float(row['val_loss']))
        val_acc_multi_loss1.append(float(row['val_acc']))
        
print(np.shape(loss_multi_loss1))

loss_multi_loss1ifelse = []
acc_multi_loss1ifelse = []
val_loss_multi_loss1ifelse = []
val_acc_multi_loss1ifelse = []

with open(log_dir + 'binary61_multi_loss_ifelse_log.csv', newline='') as csvfile:
    f_csv = csv.DictReader(csvfile)
    for row in f_csv:
        #print(type(row['loss']))#<class 'str'>
        loss_multi_loss1ifelse.append(float(row['loss']))
        acc_multi_loss1ifelse.append(float(row['acc']))
        val_loss_multi_loss1ifelse.append(float(row['val_loss']))
        val_acc_multi_loss1ifelse.append(float(row['val_acc']))
        
print(np.shape(loss_multi_loss1ifelse))

loss_multi_loss2 = []
acc_multi_loss2 = []
val_loss_multi_loss2 = []
val_acc_multi_loss2 = []

with open(log_dir + 'binary61_multi_loss2_log.csv', newline='') as csvfile:
    f_csv = csv.DictReader(csvfile)
    for row in f_csv:
        #print(type(row['loss']))#<class 'str'>
        loss_multi_loss2.append(float(row['loss']))
        acc_multi_loss2.append(float(row['acc']))
        val_loss_multi_loss2.append(float(row['val_loss']))
        val_acc_multi_loss2.append(float(row['val_acc']))
        
print(np.shape(loss_multi_loss2))

loss_multi_loss2ifelse = []
acc_multi_loss2ifelse = []
val_loss_multi_loss2ifelse = []
val_acc_multi_loss2ifelse = []

with open(log_dir + 'binary61_multi_loss2_ifelse_log.csv', newline='') as csvfile:
    f_csv = csv.DictReader(csvfile)
    for row in f_csv:
        #print(type(row['loss']))#<class 'str'>
        loss_multi_loss2ifelse.append(float(row['loss']))
        acc_multi_loss2ifelse.append(float(row['acc']))
        val_loss_multi_loss2ifelse.append(float(row['val_loss']))
        val_acc_multi_loss2ifelse.append(float(row['val_acc']))
        
print(np.shape(loss_multi_loss2ifelse))
# Out:
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)

# %%
fig = plt.figure(1)
fig.subplots_adjust(top=0.92, bottom=0.08, left=0.05, right=0.95, hspace=0.5, wspace=0.5)
ax_loss = fig.add_subplot(221)
ax_loss.set_xlabel("epoches")
ax_loss.set_ylabel("loss")
ax_loss.plot(loss_con, color='green', marker='x', linestyle='-', linewidth=1, markersize=0.1)
ax_loss.plot(loss_add, color='red', marker='x', linestyle='-', linewidth=1, markersize=0.1)
ax_loss.plot(loss_multi, color='blue', marker='x', linestyle='-', linewidth=1, markersize=0.1)
ax_loss.plot(loss_multi_loss1, color='black', marker='x', linestyle='-', linewidth=1, markersize=0.1)
ax_loss.plot(loss_multi_loss1ifelse, color='cyan', marker='x', linestyle='-', linewidth=1, markersize=0.1)
ax_loss.plot(loss_multi_loss2, color='magenta', marker='x', linestyle='-', linewidth=1, markersize=0.1)
ax_loss.plot(loss_multi_loss2ifelse, color='orange', marker='x', linestyle='-', linewidth=1, markersize=0.1)

ax_acc = fig.add_subplot(222)
ax_acc.set_xlabel("epoches")
ax_acc.set_ylabel("accuracy")
ax_acc.set_ylim(0.75, 1)
ax_acc.plot(acc_con, color='green', marker='x', linestyle='-', linewidth=1, markersize=0.1)
ax_acc.plot(acc_add, color='red', marker='x', linestyle='-', linewidth=1, markersize=0.1)
ax_acc.plot(acc_multi, color='blue', marker='x', linestyle='-', linewidth=1, markersize=0.1)
ax_acc.plot(acc_multi_loss1, color='black', marker='x', linestyle='-', linewidth=1, markersize=0.1)
ax_acc.plot(acc_multi_loss1ifelse, color='cyan', marker='x', linestyle='-', linewidth=1, markersize=0.1)
ax_acc.plot(acc_multi_loss2, color='magenta', marker='x', linestyle='-', linewidth=1, markersize=0.1)
ax_acc.plot(acc_multi_loss2ifelse, color='orange', marker='x', linestyle='-', linewidth=1, markersize=0.1)

ax_valloss = fig.add_subplot(223)
ax_valloss.set_xlabel("epoches")
ax_valloss.set_ylabel("val_loss")
ax_valloss.plot(val_loss_con,color='green', marker='x', linestyle='-', linewidth=1, markersize=0.1)
ax_valloss.plot(val_loss_add, color='red', marker='x', linestyle='-', linewidth=1, markersize=0.1)
ax_valloss.plot(val_loss_multi, color='blue', marker='x', linestyle='-', linewidth=1, markersize=0.1)
ax_valloss.plot(val_loss_multi_loss1, color='black', marker='x', linestyle='-', linewidth=1, markersize=0.1)
ax_valloss.plot(val_loss_multi_loss1ifelse, color='cyan', marker='x', linestyle='-', linewidth=1, markersize=0.1)
ax_valloss.plot(val_loss_multi_loss2, color='magenta', marker='x', linestyle='-', linewidth=1, markersize=0.1)
ax_valloss.plot(val_loss_multi_loss2ifelse, color='orange', marker='x', linestyle='-', linewidth=1, markersize=0.1)

ax_valacc = fig.add_subplot(224)
ax_valacc.set_xlabel("epoches")
ax_valacc.set_ylabel("val_accuracy")
ax_valacc.set_ylim(0.75, 0.95)
ax_valacc.plot(val_acc_con, color='green', marker='x', linestyle='-', linewidth=1, markersize=0.1)
ax_valacc.plot(val_acc_add, color='red', marker='x', linestyle='-', linewidth=1, markersize=0.1)
ax_valacc.plot(val_acc_multi, color='blue', marker='x', linestyle='-', linewidth=1, markersize=0.1)
ax_valacc.plot(val_acc_multi_loss1, color='black', marker='x', linestyle='-', linewidth=1, markersize=0.1)
ax_valacc.plot(val_acc_multi_loss1ifelse, color='cyan', marker='x', linestyle='-', linewidth=1, markersize=0.1)
ax_valacc.plot(val_acc_multi_loss2, color='magenta', marker='x', linestyle='-', linewidth=1, markersize=0.1)
ax_valacc.plot(val_acc_multi_loss2ifelse, color='orange', marker='x', linestyle='-', linewidth=1, markersize=0.1)

labels = ('concentrate', 'high_fea_prior_average', 'high_fea_prior_multi', 'high_fea_prior_multi_loss+', 'high_fea_prior_multi_loss+if', 'high_fea_prior_multi_loss2+', 'high_fea_prior_multi_loss2+if')
ax_valacc.legend(labels, loc='upper center', ncol=2, bbox_to_anchor= (-.3, -.5))#, borderaxespad=0, frameon=False, shadow=True
plt.show()
fig.savefig("../results/log1.png", dpi=256, bbox_inches="tight")

# %%
log_dir = '../'+model+'/hiarBayesGoogLeNet_PETA/'
loss = []
acc = []
val_loss = []
val_acc = []

with open(log_dir + 'binary61_log.csv', newline='') as csvfile:
    f_csv = csv.DictReader(csvfile)
    for row in f_csv:
        #print(type(row['loss']))#<class 'str'>
        loss.append(float(row['loss']))
        acc.append(float(row['acc']))
        val_loss.append(float(row['val_loss']))
        val_acc.append(float(row['val_acc']))
        
print(np.shape(loss))

fig = plt.figure(1)
fig.subplots_adjust(top=0.92, bottom=0.08, left=0.05, right=0.95, hspace=0.5, wspace=0.5)
ax_loss = fig.add_subplot(221)
ax_loss.set_xlabel("epoches")
ax_loss.set_ylabel("loss")
ax_loss.plot(loss_hiarBayesGoogLeNet, color='red', marker='x', linestyle='-', linewidth=1, markersize=0.1)
ax_loss.plot(loss, color='blue', marker='x', linestyle='-', linewidth=1, markersize=0.1)

ax_acc = fig.add_subplot(222)
ax_acc.set_xlabel("epoches")
ax_acc.set_ylabel("accuracy")
ax_acc.set_ylim(0.75, 1)
ax_acc.plot(acc_hiarBayesGoogLeNet, color='red', marker='x', linestyle='-', linewidth=1, markersize=0.1)
ax_acc.plot(acc, color='blue', marker='x', linestyle='-', linewidth=1, markersize=0.1)

ax_valloss = fig.add_subplot(223)
ax_valloss.set_xlabel("epoches")
ax_valloss.set_ylabel("val_loss")
ax_valloss.plot(val_loss_hiarBayesGoogLeNet, color='red', marker='x', linestyle='-', linewidth=1, markersize=0.1)
ax_valloss.plot(val_loss, color='blue', marker='x', linestyle='-', linewidth=1, markersize=0.1)

ax_valacc = fig.add_subplot(224)
ax_valacc.set_xlabel("epoches")
ax_valacc.set_ylabel("val_accuracy")
ax_valacc.set_ylim(0.75, 0.95)
ax_valacc.plot(val_acc_hiarBayesGoogLeNet, color='red', marker='x', linestyle='-', linewidth=1, markersize=0.1)
ax_valacc.plot(val_acc, color='blue', marker='x', linestyle='-', linewidth=1, markersize=0.1)

labels = ('binary_crossentropy', 'bayes_binary_crossentropy')
ax_valacc.legend(labels, loc='upper center', ncol=2, bbox_to_anchor= (-.3, -.5))#, borderaxespad=0, frameon=False, shadow=True
plt.show()
fig.savefig("../results/log1.png", dpi=256, bbox_inches="tight")
