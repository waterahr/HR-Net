# %%
# -*- coding: utf-8 -*-
import os
os.environ['CUDA_VISIBLE_DEVICES'] = ""
from keras.applications import InceptionV3
from keras.applications.inception_v3 import preprocess_input
from keras.preprocessing import image
from keras.models import Model
from keras.applications.imagenet_utils import decode_predictions
import numpy as np
import cv2
from cv2 import *
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy as sp
from scipy.misc import toimage
import sys
sys.path.append("..")
from src.network.hiarGoogLenet import hiarGoogLeNet
from src.network.GoogleLenet import GoogLeNet
from src.network.hiarGoogLenet_high import hiarGoogLeNet_high

low_level = [27, 32, 50, 56]#, 61, 62, 63, 64
mid_level = [0, 6, 7, 8, 9, 11, 12, 13, 17, 20, 21, 22, 23, 24, 25, 26, 28, 29, 30, 33, 35, 36, 37, 38, 39, 41, 42, 43, 44, 45, 46, 47, 48, 49, 51, 52, 53, 54, 55, 57, 58, 59, 60]
high_level = [1, 2, 3, 4, 5, 10, 14, 15, 16, 18, 19, 31, 34, 40]
image_width = 75
image_height = 160
model_h = hiarGoogLeNet.build(image_height, image_width, 3, [len(low_level), len(mid_level), len(high_level)])
model_h.load_weights("/home/anhaoran/codes/pedestrian_attibutes_wpal/models/imagenet_models/hiarGoogLeNet_PETA/binary61_final_model.h5")
model_g = GoogLeNet.build(image_height, image_width, 3, 61)
model_g.load_weights("../models/imagenet_models/GoogLeNet_PETA/binary61_final_model.h5")
model_gh = hiarGoogLeNet_high.build(image_height, image_width, 3, [len(low_level), len(mid_level), len(high_level)])
model_gh.load_weights("../models/imagenet_models/hiarGoogLeNet_PETA/binary61_high_final_model.h5")
# Out:
# Using TensorFlow backend.
# ImageNet...

# %%
model_gh = hiarGoogLeNet_high.build(image_height, image_width, 3, [len(low_level), len(mid_level), len(high_level)])
model_gh.load_weights("../models/imagenet_models/hiarGoogLeNet_PETA/binary61_high_final_model.h5")

# %%
def load_original(img_path, img_height, img_width):
    # 把原始图片压缩为 299*299大小
    img = image.load_img(img_path, target_size=(image_height, image_width, 3))
    plt.figure(0)
    plt.subplot(211)
    plt.imshow(img)
    return img

"""
def load_fine_tune_googlenet_v3(img):
    # 加载fine-tuning googlenet v3模型，并做预测
    model = InceptionV3(include_top=True, weights='imagenet')
    model.summary()
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    preds = model.predict(x)
    print('Predicted:', decode_predictions(preds))
    plt.subplot(212)
    plt.plot(preds.ravel())
    plt.show()
    return model, x
"""
# Out:
# "\ndef load_fine_tune_googlenet_v3(img):\n    # 加载fine-tuning googlenet v3模型，并做预测\n    model = InceptionV3(include_top=True, weights='imagenet')\n    model.summary()\n    x = image.img_to_array(img)\n    x = np.expand_dims(x, axis=0)\n    x = preprocess_input(x)\n    preds = model.predict(x)\n    print('Predicted:', decode_predictions(preds))\n    plt.subplot(212)\n    plt.plot(preds.ravel())\n    plt.show()\n    return model, x\n"

# %%
def extract_features(model, x, layer_id, filters, layer_num_list):
    '''
    提取指定模型指定层指定数目的feature map并输出到一幅图上.
    :param ins: 模型实例
    if len(ins) != 2:
        print('parameter error:(model, instance)')
        return None
    :param layer_id: 提取指定层特征
    :param filters: 每层提取的feature map数
    :param layer_num_list: 一共提取多少层feature map
    :return: None
    '''
    #model = ins[0]
    #x = ins[1]
    if type(layer_id) == type(1):
        model_extractfeatures = Model(inputs=model.input, outputs=model.get_layer(index=layer_id).output)
    else:
        model_extractfeatures = Model(inputs=model.input, outputs=model.get_layer(name=layer_id).output)
    #model_extractfeatures.summary()
    fc2_features = model_extractfeatures.predict(x)
    if filters > len(fc2_features[0][0][0]):
        print('layer number error.', len(fc2_features[0][0][0]),',',filters)
        return None
    for i in range(filters):
        #plt.subplots_adjust(left=0, right=1, bottom=0, top=1)
        plt.subplot(filters, len(layer_num_list), layer_num_list.index(layer_id) + 1 + i * len(layer_num_list) )
        plt.axis("off")
        if i < len(fc2_features[0][0][0]):
            plt.imshow(fc2_features[0, :, :, i])

# 层数、模型、卷积核数
def extract_features_batch(model, x, filters, layer_num_list, path):
    '''
    批量提取特征
    :param layer_num: 层数
    :param model: 模型
    :param filters: feature map数
    :return: None
    '''
    #plt.figure(figsize=(filters, layer_num))
    plt.subplot(filters, len(layer_num_list), 1)
    for i in layer_num_list:
        extract_features(model, x, i, filters, layer_num_list)
    plt.savefig(path, dpi=500, quality=95)
    plt.show()

def extract_features_with_layers(model, instance, layer_indexes, img_height=160, img_width=75):
    '''
    提取hypercolumn并可视化.
    :param layers_extract: 指定层列表
    :return: None
    '''
    hc = extract_hypercolumn(model, instance, layer_indexes, img_height, img_width)
    ave = np.average(hc.transpose(1, 2, 0), axis=2)
    plt.imshow(ave)
    plt.show()

def extract_hypercolumn(model, instance, layer_indexes, img_height=160, img_width=75):
    '''
    提取指定模型指定层的hypercolumn向量
    :param model: 模型
    :param layer_indexes: 层id
    :param instance: 输入
    :return:
    '''
    feature_maps = []
    for i in layer_indexes:
        feature_maps.append(Model(inputs=model.input, outputs=model.get_layer(index=i).output).predict(instance))
    hypercolumns = []
    for convmap in feature_maps:
        for i in range(len(convmap[0][0][0])):
            upscaled = sp.misc.imresize(convmap[0, :, :, i], size=(img_height, img_width), mode="F", interp='bilinear')
            hypercolumns.append(upscaled)
    return np.asarray(hypercolumns)


img_path = '/home/anhaoran/data/pedestrian_attributes_PETA/PETA/3DPeS/archive/191_494_FRAME_319_RGB.bmp'
img = load_original(img_path, image_height, image_width)
img_arr = image.img_to_array(img)
img_arr = np.expand_dims(img_arr, axis=0)
print(img_arr.shape)

extract_features_batch(model_h, img_arr, 10, [1, 2, 3, 4, 5, 10, 15, 20, 25, 30, 40, 50, 70, 90, 110, 130], '../results/samples/sample_h.jpg')
extract_features_batch(model_g, img_arr, 10, [1, 2, 3, 4, 5, 10, 15, 20, 25, 30, 40, 50, 70, 90, 110, 130], '../results/samples/sample_g.jpg')
extract_features_batch(model_gh, img_arr, 10, [1, 2, 3, 4, 5, 10, 15, 20, 25, 30, 40, 50, 70, 90, 110, 130], '../results/samples/sample_gh.jpg')
#extract_features_with_layers(model_h, img_arr, [1, 4, 7])
#extract_features_with_layers(model_h, img_arr, [1, 4, 7, 10, 11, 14, 17])
# Out:
# (1, 160, 75, 3)
# /home/anhaoran/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# # Low&Mid level feature map

# %%
model_h.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 160, 75, 3)   0
# __________________________________________________________________________________________________
# conv1_7x7_s2 (Conv2D)           (None, 80, 38, 64)   9472        input_1[0][0]
# __________________________________________________________________________________________________
# conv1_7x7_s2_bn (BatchNormaliza (None, 80, 38, 64)   256         conv1_7x7_s2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 40, 19, 64)   0           conv1_7x7_s2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_3x3 (Conv2D)              (None, 40, 19, 192)  110784      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2_3x3_bn (BatchNormalizatio (None, 40, 19, 192)  768         conv2_3x3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 20, 10, 192)  0           conv2_3x3_bn[0][0]
# __________________________________________________________________________________________________
# inception_3a_3x3_reduce (Conv2D (None, 20, 10, 96)   18528       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# inception_3a5x5_reduce (Conv2D) (None, 20, 10, 16)   3088        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# inception_3a_3x3_reduce_bn (Bat (None, 20, 10, 96)   384         inception_3a_3x3_reduce[0][0]
# __________________________________________________________________________________________________
# inception_3a5x5_reduce_bn (Batc (None, 20, 10, 16)   64          inception_3a5x5_reduce[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 20, 10, 192)  0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# inception_3a_1x1 (Conv2D)       (None, 20, 10, 64)   12352       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# inception_3a_3x3 (Conv2D)       (None, 20, 10, 128)  110720      inception_3a_3x3_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_3a_5x5 (Conv2D)       (None, 20, 10, 32)   12832       inception_3a5x5_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_3a_pool_proj (Conv2D) (None, 20, 10, 32)   6176        max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# inception_3a_1x1_bn (BatchNorma (None, 20, 10, 64)   256         inception_3a_1x1[0][0]
# __________________________________________________________________________________________________
# inception_3a_3x3_bn (BatchNorma (None, 20, 10, 128)  512         inception_3a_3x3[0][0]
# __________________________________________________________________________________________________
# inception_3a_5x5_bn (BatchNorma (None, 20, 10, 32)   128         inception_3a_5x5[0][0]
# __________________________________________________________________________________________________
# inception_3a_pool_proj_bn (Batc (None, 20, 10, 32)   128         inception_3a_pool_proj[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 20, 10, 256)  0           inception_3a_1x1_bn[0][0]
#                                                                  inception_3a_3x3_bn[0][0]
#                                                                  inception_3a_5x5_bn[0][0]
#                                                                  inception_3a_pool_proj_bn[0][0]
# __________________________________________________________________________________________________
# inception_3b_3x3_reduce (Conv2D (None, 20, 10, 128)  32896       concatenate_1[0][0]
# __________________________________________________________________________________________________
# inception_3b5x5_reduce (Conv2D) (None, 20, 10, 32)   8224        concatenate_1[0][0]
# __________________________________________________________________________________________________
# inception_3b_3x3_reduce_bn (Bat (None, 20, 10, 128)  512         inception_3b_3x3_reduce[0][0]
# __________________________________________________________________________________________________
# inception_3b5x5_reduce_bn (Batc (None, 20, 10, 32)   128         inception_3b5x5_reduce[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 20, 10, 256)  0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# inception_3b_1x1 (Conv2D)       (None, 20, 10, 128)  32896       concatenate_1[0][0]
# __________________________________________________________________________________________________
# inception_3b_3x3 (Conv2D)       (None, 20, 10, 192)  221376      inception_3b_3x3_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_3b_5x5 (Conv2D)       (None, 20, 10, 96)   76896       inception_3b5x5_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_3b_pool_proj (Conv2D) (None, 20, 10, 64)   16448       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# inception_3b_1x1_bn (BatchNorma (None, 20, 10, 128)  512         inception_3b_1x1[0][0]
# __________________________________________________________________________________________________
# inception_3b_3x3_bn (BatchNorma (None, 20, 10, 192)  768         inception_3b_3x3[0][0]
# __________________________________________________________________________________________________
# inception_3b_5x5_bn (BatchNorma (None, 20, 10, 96)   384         inception_3b_5x5[0][0]
# __________________________________________________________________________________________________
# inception_3b_pool_proj_bn (Batc (None, 20, 10, 64)   256         inception_3b_pool_proj[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 20, 10, 480)  0           inception_3b_1x1_bn[0][0]
#                                                                  inception_3b_3x3_bn[0][0]
#                                                                  inception_3b_5x5_bn[0][0]
#                                                                  inception_3b_pool_proj_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 10, 5, 480)   0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# inception_4a_3x3_reduce (Conv2D (None, 10, 5, 96)    46176       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# inception_4a5x5_reduce (Conv2D) (None, 10, 5, 16)    7696        max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# inception_4a_3x3_reduce_bn (Bat (None, 10, 5, 96)    384         inception_4a_3x3_reduce[0][0]
# __________________________________________________________________________________________________
# inception_4a5x5_reduce_bn (Batc (None, 10, 5, 16)    64          inception_4a5x5_reduce[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 10, 5, 480)   0           max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# inception_4a_1x1 (Conv2D)       (None, 10, 5, 192)   92352       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# inception_4a_3x3 (Conv2D)       (None, 10, 5, 208)   179920      inception_4a_3x3_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_4a_5x5 (Conv2D)       (None, 10, 5, 48)    19248       inception_4a5x5_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_4a_pool_proj (Conv2D) (None, 10, 5, 64)    30784       max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# inception_4a_1x1_bn (BatchNorma (None, 10, 5, 192)   768         inception_4a_1x1[0][0]
# __________________________________________________________________________________________________
# inception_4a_3x3_bn (BatchNorma (None, 10, 5, 208)   832         inception_4a_3x3[0][0]
# __________________________________________________________________________________________________
# inception_4a_5x5_bn (BatchNorma (None, 10, 5, 48)    192         inception_4a_5x5[0][0]
# __________________________________________________________________________________________________
# inception_4a_pool_proj_bn (Batc (None, 10, 5, 64)    256         inception_4a_pool_proj[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 10, 5, 512)   0           inception_4a_1x1_bn[0][0]
#                                                                  inception_4a_3x3_bn[0][0]
#                                                                  inception_4a_5x5_bn[0][0]
#                                                                  inception_4a_pool_proj_bn[0][0]
# __________________________________________________________________________________________________
# inception_4b_3x3_reduce (Conv2D (None, 10, 5, 112)   57456       concatenate_3[0][0]
# __________________________________________________________________________________________________
# inception_4b5x5_reduce (Conv2D) (None, 10, 5, 24)    12312       concatenate_3[0][0]
# __________________________________________________________________________________________________
# inception_4b_3x3_reduce_bn (Bat (None, 10, 5, 112)   448         inception_4b_3x3_reduce[0][0]
# __________________________________________________________________________________________________
# inception_4b5x5_reduce_bn (Batc (None, 10, 5, 24)    96          inception_4b5x5_reduce[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 10, 5, 512)   0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# inception_4b_1x1 (Conv2D)       (None, 10, 5, 160)   82080       concatenate_3[0][0]
# __________________________________________________________________________________________________
# inception_4b_3x3 (Conv2D)       (None, 10, 5, 224)   226016      inception_4b_3x3_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_4b_5x5 (Conv2D)       (None, 10, 5, 64)    38464       inception_4b5x5_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_4b_pool_proj (Conv2D) (None, 10, 5, 64)    32832       max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# inception_4b_1x1_bn (BatchNorma (None, 10, 5, 160)   640         inception_4b_1x1[0][0]
# __________________________________________________________________________________________________
# inception_4b_3x3_bn (BatchNorma (None, 10, 5, 224)   896         inception_4b_3x3[0][0]
# __________________________________________________________________________________________________
# inception_4b_5x5_bn (BatchNorma (None, 10, 5, 64)    256         inception_4b_5x5[0][0]
# __________________________________________________________________________________________________
# inception_4b_pool_proj_bn (Batc (None, 10, 5, 64)    256         inception_4b_pool_proj[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 10, 5, 512)   0           inception_4b_1x1_bn[0][0]
#                                                                  inception_4b_3x3_bn[0][0]
#                                                                  inception_4b_5x5_bn[0][0]
#                                                                  inception_4b_pool_proj_bn[0][0]
# __________________________________________________________________________________________________
# inception_4c_3x3_reduce (Conv2D (None, 10, 5, 128)   65664       concatenate_4[0][0]
# __________________________________________________________________________________________________
# inception_4c5x5_reduce (Conv2D) (None, 10, 5, 24)    12312       concatenate_4[0][0]
# __________________________________________________________________________________________________
# inception_4c_3x3_reduce_bn (Bat (None, 10, 5, 128)   512         inception_4c_3x3_reduce[0][0]
# __________________________________________________________________________________________________
# inception_4c5x5_reduce_bn (Batc (None, 10, 5, 24)    96          inception_4c5x5_reduce[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 10, 5, 512)   0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# inception_4c_1x1 (Conv2D)       (None, 10, 5, 128)   65664       concatenate_4[0][0]
# __________________________________________________________________________________________________
# inception_4c_3x3 (Conv2D)       (None, 10, 5, 256)   295168      inception_4c_3x3_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_4c_5x5 (Conv2D)       (None, 10, 5, 64)    38464       inception_4c5x5_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_4c_pool_proj (Conv2D) (None, 10, 5, 64)    32832       max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# inception_4c_1x1_bn (BatchNorma (None, 10, 5, 128)   512         inception_4c_1x1[0][0]
# __________________________________________________________________________________________________
# inception_4c_3x3_bn (BatchNorma (None, 10, 5, 256)   1024        inception_4c_3x3[0][0]
# __________________________________________________________________________________________________
# inception_4c_5x5_bn (BatchNorma (None, 10, 5, 64)    256         inception_4c_5x5[0][0]
# __________________________________________________________________________________________________
# inception_4c_pool_proj_bn (Batc (None, 10, 5, 64)    256         inception_4c_pool_proj[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 10, 5, 512)   0           inception_4c_1x1_bn[0][0]
#                                                                  inception_4c_3x3_bn[0][0]
#                                                                  inception_4c_5x5_bn[0][0]
#                                                                  inception_4c_pool_proj_bn[0][0]
# __________________________________________________________________________________________________
# inception_4d_3x3_reduce (Conv2D (None, 10, 5, 144)   73872       concatenate_5[0][0]
# __________________________________________________________________________________________________
# inception_4d5x5_reduce (Conv2D) (None, 10, 5, 32)    16416       concatenate_5[0][0]
# __________________________________________________________________________________________________
# inception_4d_3x3_reduce_bn (Bat (None, 10, 5, 144)   576         inception_4d_3x3_reduce[0][0]
# __________________________________________________________________________________________________
# inception_4d5x5_reduce_bn (Batc (None, 10, 5, 32)    128         inception_4d5x5_reduce[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 10, 5, 512)   0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# inception_4d_1x1 (Conv2D)       (None, 10, 5, 112)   57456       concatenate_5[0][0]
# __________________________________________________________________________________________________
# inception_4d_3x3 (Conv2D)       (None, 10, 5, 288)   373536      inception_4d_3x3_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_4d_5x5 (Conv2D)       (None, 10, 5, 64)    51264       inception_4d5x5_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_4d_pool_proj (Conv2D) (None, 10, 5, 64)    32832       max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# inception_4d_1x1_bn (BatchNorma (None, 10, 5, 112)   448         inception_4d_1x1[0][0]
# __________________________________________________________________________________________________
# inception_4d_3x3_bn (BatchNorma (None, 10, 5, 288)   1152        inception_4d_3x3[0][0]
# __________________________________________________________________________________________________
# inception_4d_5x5_bn (BatchNorma (None, 10, 5, 64)    256         inception_4d_5x5[0][0]
# __________________________________________________________________________________________________
# inception_4d_pool_proj_bn (Batc (None, 10, 5, 64)    256         inception_4d_pool_proj[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 10, 5, 528)   0           inception_4d_1x1_bn[0][0]
#                                                                  inception_4d_3x3_bn[0][0]
#                                                                  inception_4d_5x5_bn[0][0]
#                                                                  inception_4d_pool_proj_bn[0][0]
# __________________________________________________________________________________________________
# inception_4e_3x3_reduce (Conv2D (None, 10, 5, 160)   84640       concatenate_6[0][0]
# __________________________________________________________________________________________________
# inception_4e5x5_reduce (Conv2D) (None, 10, 5, 32)    16928       concatenate_6[0][0]
# __________________________________________________________________________________________________
# inception_4e_3x3_reduce_bn (Bat (None, 10, 5, 160)   640         inception_4e_3x3_reduce[0][0]
# __________________________________________________________________________________________________
# inception_4e5x5_reduce_bn (Batc (None, 10, 5, 32)    128         inception_4e5x5_reduce[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 10, 5, 528)   0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# inception_4e_1x1 (Conv2D)       (None, 10, 5, 256)   135424      concatenate_6[0][0]
# __________________________________________________________________________________________________
# inception_4e_3x3 (Conv2D)       (None, 10, 5, 320)   461120      inception_4e_3x3_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_4e_5x5 (Conv2D)       (None, 10, 5, 128)   102528      inception_4e5x5_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_4e_pool_proj (Conv2D) (None, 10, 5, 128)   67712       max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# inception_4e_1x1_bn (BatchNorma (None, 10, 5, 256)   1024        inception_4e_1x1[0][0]
# __________________________________________________________________________________________________
# inception_4e_3x3_bn (BatchNorma (None, 10, 5, 320)   1280        inception_4e_3x3[0][0]
# __________________________________________________________________________________________________
# inception_4e_5x5_bn (BatchNorma (None, 10, 5, 128)   512         inception_4e_5x5[0][0]
# __________________________________________________________________________________________________
# inception_4e_pool_proj_bn (Batc (None, 10, 5, 128)   512         inception_4e_pool_proj[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 10, 5, 832)   0           inception_4e_1x1_bn[0][0]
#                                                                  inception_4e_3x3_bn[0][0]
#                                                                  inception_4e_5x5_bn[0][0]
#                                                                  inception_4e_pool_proj_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 5, 3, 832)    0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# inception_5a_3x3_reduce (Conv2D (None, 5, 3, 160)    133280      max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# inception_5a5x5_reduce (Conv2D) (None, 5, 3, 32)     26656       max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# inception_5a_3x3_reduce_bn (Bat (None, 5, 3, 160)    640         inception_5a_3x3_reduce[0][0]
# __________________________________________________________________________________________________
# inception_5a5x5_reduce_bn (Batc (None, 5, 3, 32)     128         inception_5a5x5_reduce[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 5, 3, 832)    0           max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# inception_5a_1x1 (Conv2D)       (None, 5, 3, 256)    213248      max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# inception_5a_3x3 (Conv2D)       (None, 5, 3, 320)    461120      inception_5a_3x3_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_5a_5x5 (Conv2D)       (None, 5, 3, 128)    102528      inception_5a5x5_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_5a_pool_proj (Conv2D) (None, 5, 3, 128)    106624      max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# inception_5a_1x1_bn (BatchNorma (None, 5, 3, 256)    1024        inception_5a_1x1[0][0]
# __________________________________________________________________________________________________
# inception_5a_3x3_bn (BatchNorma (None, 5, 3, 320)    1280        inception_5a_3x3[0][0]
# __________________________________________________________________________________________________
# inception_5a_5x5_bn (BatchNorma (None, 5, 3, 128)    512         inception_5a_5x5[0][0]
# __________________________________________________________________________________________________
# inception_5a_pool_proj_bn (Batc (None, 5, 3, 128)    512         inception_5a_pool_proj[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 5, 3, 832)    0           inception_5a_1x1_bn[0][0]
#                                                                  inception_5a_3x3_bn[0][0]
#                                                                  inception_5a_5x5_bn[0][0]
#                                                                  inception_5a_pool_proj_bn[0][0]
# __________________________________________________________________________________________________
# inception_5b_3x3_reduce (Conv2D (None, 5, 3, 192)    159936      concatenate_8[0][0]
# __________________________________________________________________________________________________
# inception_5b5x5_reduce (Conv2D) (None, 5, 3, 48)     39984       concatenate_8[0][0]
# __________________________________________________________________________________________________
# inception_5b_3x3_reduce_bn (Bat (None, 5, 3, 192)    768         inception_5b_3x3_reduce[0][0]
# __________________________________________________________________________________________________
# inception_5b5x5_reduce_bn (Batc (None, 5, 3, 48)     192         inception_5b5x5_reduce[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_13 (MaxPooling2D) (None, 5, 3, 832)    0           concatenate_8[0][0]
# __________________________________________________________________________________________________
# inception_5b_1x1 (Conv2D)       (None, 5, 3, 384)    319872      concatenate_8[0][0]
# __________________________________________________________________________________________________
# inception_5b_3x3 (Conv2D)       (None, 5, 3, 384)    663936      inception_5b_3x3_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_5b_5x5 (Conv2D)       (None, 5, 3, 128)    153728      inception_5b5x5_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_5b_pool_proj (Conv2D) (None, 5, 3, 128)    106624      max_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# inception_5b_1x1_bn (BatchNorma (None, 5, 3, 384)    1536        inception_5b_1x1[0][0]
# __________________________________________________________________________________________________
# inception_5b_3x3_bn (BatchNorma (None, 5, 3, 384)    1536        inception_5b_3x3[0][0]
# __________________________________________________________________________________________________
# inception_5b_5x5_bn (BatchNorma (None, 5, 3, 128)    512         inception_5b_5x5[0][0]
# __________________________________________________________________________________________________
# inception_5b_pool_proj_bn (Batc (None, 5, 3, 128)    512         inception_5b_pool_proj[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 5, 3, 1024)   0           inception_5b_1x1_bn[0][0]
#                                                                  inception_5b_3x3_bn[0][0]
#                                                                  inception_5b_5x5_bn[0][0]
#                                                                  inception_5b_pool_proj_bn[0][0]
# __________________________________________________________________________________________________
# conv1_e (Conv2D)                (None, 10, 5, 512)   2359808     concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2_e (Conv2D)                (None, 10, 5, 512)   2433536     concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv3_e (Conv2D)                (None, 5, 3, 1024)   9438208     concatenate_9[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 512)          0           conv1_e[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 512)          0           conv2_e[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_3 (Glo (None, 1024)         0           conv3_e[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 512)          262656      global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 512)          262656      global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1024)         1049600     global_average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# low (Dense)                     (None, 4)            2052        dense_1[0][0]
# __________________________________________________________________________________________________
# middle (Dense)                  (None, 43)           22059       dense_2[0][0]
# __________________________________________________________________________________________________
# high (Dense)                    (None, 14)           14350       dense_3[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 61)           0           low[0][0]
#                                                                  middle[0][0]
#                                                                  high[0][0]
# ==================================================================================================
# Total params: 21,843,181
# Trainable params: 21,828,749
# Non-trainable params: 14,432
# __________________________________________________________________________________________________

# %%
def extract_features_hiar_models(model, x, layer_id, filters, layer_num_list):
    '''
    提取指定模型指定层指定数目的feature map并输出到一幅图上.
    :param ins: 模型实例
    if len(ins) != 2:
        print('parameter error:(model, instance)')
        return None
    :param layer_id: 提取指定层特征
    :param filters: 每层提取的feature map数
    :param layer_num_list: 一共提取多少层feature map
    :return: None
    '''
    if type(layer_id) == type(1):
        model_extractfeatures = Model(inputs=model[i].input, outputs=model[i].get_layer(index=layer_id).output)
    else:
        model_extractfeatures = Model(inputs=model[i].input, outputs=model[i].get_layer(name=layer_id).output)
    #model_extractfeatures.summary()
    fc2_features = model_extractfeatures.predict(x)
    if filters > len(fc2_features[0][0][0]):
        print('layer number error.', len(fc2_features[0][0][0]),',',filters)
        return None
    for i in range(filters):
        #plt.subplots_adjust(left=0, right=1, bottom=0, top=1)
        plt.subplot(filters, len(layer_num_list), layer_num_list.index(layer_id) + 1 + i * len(layer_num_list) )
        plt.axis("off")
        if i < len(fc2_features[0][0][0]):
            plt.imshow(fc2_features[0, :, :, i])

# 层数、模型、卷积核数
def extract_features_batch_hiar_models(model, x, filters, layer_num_list, path):
    '''
    批量提取特征
    :param layer_num: 层数
    :param model: 模型
    :param filters: feature map数
    :return: None
    '''
    #plt.figure(figsize=(filters, layer_num))
    plt.subplot(filters, len(layer_num_list), 1)
    for i in layer_num_list:
        extract_features_hiar_models(model, x, i, filters, layer_num_list)
    plt.savefig(path, dpi=250, quality=95)
    plt.show()
    

for i in range(20):
    print("filter_", str(i))
    extract_features_batch_hiar_models(model_h, img_arr, i, [1, 2, 3, 4, 5, 10, 15, 20, 25, 30, 40, 50, 70, 90, 110, 130], '../results/samples/sample_all_model_filter'+str(i)+'.jpg')

# %% [markdown]
# # base feature map

# %%
def extract_features_allmodels(model, x, layer_id, filter_id, layer_num_list):
    '''
    提取指定模型指定层指定数目的feature map并输出到一幅图上.
    :param ins: 模型实例
    if len(ins) != 2:
        print('parameter error:(model, instance)')
        return None
    :param layer_id: 提取指定层特征
    :param filters: 每层提取的feature map数
    :param layer_num_list: 一共提取多少层feature map
    :return: None
    '''
    for i in range(len(model)):
        if type(layer_id) == type(1):
            model_extractfeatures = Model(inputs=model[i].input, outputs=model[i].get_layer(index=layer_id).output)
        else:
            model_extractfeatures = Model(inputs=model[i].input, outputs=model[i].get_layer(name=layer_id).output)
        #model_extractfeatures.summary()
        fc2_features = model_extractfeatures.predict(x)
        if filter_id > len(fc2_features[0][0][0]):
            print('layer number error.', len(fc2_features[0][0][0]),',',filter_id)
            return None
        #plt.subplots_adjust(left=0, right=1, bottom=0, top=1)
        plt.subplot(len(model), len(layer_num_list), layer_num_list.index(layer_id) + 1 + i * len(layer_num_list) )
        plt.axis("off")
        if filter_id < len(fc2_features[0][0][0]):
            plt.imshow(fc2_features[0, :, :, filter_id])
            plt.savefig("../results/1.jpg", dpi=250, quality=95)

# 层数、模型、卷积核数
def extract_features_batch_allmodels(model, x, filter_id, layer_num_list, path):
    '''
    批量提取特征
    :param layer_num: 层数
    :param model: 模型
    :param filters: feature map数
    :return: None
    '''
    #plt.figure(figsize=(filters, layer_num))
    plt.subplot(len(model), len(layer_num_list), 1)
    for i in layer_num_list:
        extract_features_allmodels(model, x, i, filter_id, layer_num_list)
    plt.savefig(path, dpi=250, quality=95)
    plt.show()
    

#for i in range(20):
#    print("filter_", str(i))
extract_features_batch_allmodels([model_h, model_g], img_arr, 0, [1, 2, 3, 4, 5, 10, 15, 20, 25, 30, 40, 50, 70, 90, 110, 130], '../results/samples/sample_all_model_filter'+str(i)+'.jpg')
# Out:
# /home/anhaoran/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
Model(inputs=model.input, outputs=model.get_layer(index=layer_id).output)

# %% [markdown]
# # Weights

# %%
from src.network.hiarBayesGoogLenet import hiarBayesGoogLeNet

# %%
model_hr = hiarBayesGoogLeNet.build(image_height, image_width, 3, [len(low_level), len(mid_level), len(high_level)])
model_hr.load_weights("/home/anhaoran/codes/pedestrian_attibutes_wpal/models/imagenet_models/hiarBayesGoogLeNet_PETA/binary61_multi_final_model.h5")

# %%
model_hr.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            (None, 160, 75, 3)   0
# __________________________________________________________________________________________________
# conv1_7x7_s2 (Conv2D)           (None, 80, 38, 64)   9472        input_4[0][0]
# __________________________________________________________________________________________________
# conv1_7x7_s2_bn (BatchNormaliza (None, 80, 38, 64)   256         conv1_7x7_s2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_40 (MaxPooling2D) (None, 40, 19, 64)   0           conv1_7x7_s2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_3x3 (Conv2D)              (None, 40, 19, 192)  110784      max_pooling2d_40[0][0]
# __________________________________________________________________________________________________
# conv2_3x3_bn (BatchNormalizatio (None, 40, 19, 192)  768         conv2_3x3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_41 (MaxPooling2D) (None, 20, 10, 192)  0           conv2_3x3_bn[0][0]
# __________________________________________________________________________________________________
# inception_3a_3x3_reduce (Conv2D (None, 20, 10, 96)   18528       max_pooling2d_41[0][0]
# __________________________________________________________________________________________________
# inception_3a5x5_reduce (Conv2D) (None, 20, 10, 16)   3088        max_pooling2d_41[0][0]
# __________________________________________________________________________________________________
# inception_3a_3x3_reduce_bn (Bat (None, 20, 10, 96)   384         inception_3a_3x3_reduce[0][0]
# __________________________________________________________________________________________________
# inception_3a5x5_reduce_bn (Batc (None, 20, 10, 16)   64          inception_3a5x5_reduce[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_42 (MaxPooling2D) (None, 20, 10, 192)  0           max_pooling2d_41[0][0]
# __________________________________________________________________________________________________
# inception_3a_1x1 (Conv2D)       (None, 20, 10, 64)   12352       max_pooling2d_41[0][0]
# __________________________________________________________________________________________________
# inception_3a_3x3 (Conv2D)       (None, 20, 10, 128)  110720      inception_3a_3x3_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_3a_5x5 (Conv2D)       (None, 20, 10, 32)   12832       inception_3a5x5_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_3a_pool_proj (Conv2D) (None, 20, 10, 32)   6176        max_pooling2d_42[0][0]
# __________________________________________________________________________________________________
# inception_3a_1x1_bn (BatchNorma (None, 20, 10, 64)   256         inception_3a_1x1[0][0]
# __________________________________________________________________________________________________
# inception_3a_3x3_bn (BatchNorma (None, 20, 10, 128)  512         inception_3a_3x3[0][0]
# __________________________________________________________________________________________________
# inception_3a_5x5_bn (BatchNorma (None, 20, 10, 32)   128         inception_3a_5x5[0][0]
# __________________________________________________________________________________________________
# inception_3a_pool_proj_bn (Batc (None, 20, 10, 32)   128         inception_3a_pool_proj[0][0]
# __________________________________________________________________________________________________
# concatenate_29 (Concatenate)    (None, 20, 10, 256)  0           inception_3a_1x1_bn[0][0]
#                                                                  inception_3a_3x3_bn[0][0]
#                                                                  inception_3a_5x5_bn[0][0]
#                                                                  inception_3a_pool_proj_bn[0][0]
# __________________________________________________________________________________________________
# inception_3b_3x3_reduce (Conv2D (None, 20, 10, 128)  32896       concatenate_29[0][0]
# __________________________________________________________________________________________________
# inception_3b5x5_reduce (Conv2D) (None, 20, 10, 32)   8224        concatenate_29[0][0]
# __________________________________________________________________________________________________
# inception_3b_3x3_reduce_bn (Bat (None, 20, 10, 128)  512         inception_3b_3x3_reduce[0][0]
# __________________________________________________________________________________________________
# inception_3b5x5_reduce_bn (Batc (None, 20, 10, 32)   128         inception_3b5x5_reduce[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_43 (MaxPooling2D) (None, 20, 10, 256)  0           concatenate_29[0][0]
# __________________________________________________________________________________________________
# inception_3b_1x1 (Conv2D)       (None, 20, 10, 128)  32896       concatenate_29[0][0]
# __________________________________________________________________________________________________
# inception_3b_3x3 (Conv2D)       (None, 20, 10, 192)  221376      inception_3b_3x3_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_3b_5x5 (Conv2D)       (None, 20, 10, 96)   76896       inception_3b5x5_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_3b_pool_proj (Conv2D) (None, 20, 10, 64)   16448       max_pooling2d_43[0][0]
# __________________________________________________________________________________________________
# inception_3b_1x1_bn (BatchNorma (None, 20, 10, 128)  512         inception_3b_1x1[0][0]
# __________________________________________________________________________________________________
# inception_3b_3x3_bn (BatchNorma (None, 20, 10, 192)  768         inception_3b_3x3[0][0]
# __________________________________________________________________________________________________
# inception_3b_5x5_bn (BatchNorma (None, 20, 10, 96)   384         inception_3b_5x5[0][0]
# __________________________________________________________________________________________________
# inception_3b_pool_proj_bn (Batc (None, 20, 10, 64)   256         inception_3b_pool_proj[0][0]
# __________________________________________________________________________________________________
# concatenate_30 (Concatenate)    (None, 20, 10, 480)  0           inception_3b_1x1_bn[0][0]
#                                                                  inception_3b_3x3_bn[0][0]
#                                                                  inception_3b_5x5_bn[0][0]
#                                                                  inception_3b_pool_proj_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_44 (MaxPooling2D) (None, 10, 5, 480)   0           concatenate_30[0][0]
# __________________________________________________________________________________________________
# inception_4a_3x3_reduce (Conv2D (None, 10, 5, 96)    46176       max_pooling2d_44[0][0]
# __________________________________________________________________________________________________
# inception_4a5x5_reduce (Conv2D) (None, 10, 5, 16)    7696        max_pooling2d_44[0][0]
# __________________________________________________________________________________________________
# inception_4a_3x3_reduce_bn (Bat (None, 10, 5, 96)    384         inception_4a_3x3_reduce[0][0]
# __________________________________________________________________________________________________
# inception_4a5x5_reduce_bn (Batc (None, 10, 5, 16)    64          inception_4a5x5_reduce[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_45 (MaxPooling2D) (None, 10, 5, 480)   0           max_pooling2d_44[0][0]
# __________________________________________________________________________________________________
# inception_4a_1x1 (Conv2D)       (None, 10, 5, 192)   92352       max_pooling2d_44[0][0]
# __________________________________________________________________________________________________
# inception_4a_3x3 (Conv2D)       (None, 10, 5, 208)   179920      inception_4a_3x3_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_4a_5x5 (Conv2D)       (None, 10, 5, 48)    19248       inception_4a5x5_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_4a_pool_proj (Conv2D) (None, 10, 5, 64)    30784       max_pooling2d_45[0][0]
# __________________________________________________________________________________________________
# inception_4a_1x1_bn (BatchNorma (None, 10, 5, 192)   768         inception_4a_1x1[0][0]
# __________________________________________________________________________________________________
# inception_4a_3x3_bn (BatchNorma (None, 10, 5, 208)   832         inception_4a_3x3[0][0]
# __________________________________________________________________________________________________
# inception_4a_5x5_bn (BatchNorma (None, 10, 5, 48)    192         inception_4a_5x5[0][0]
# __________________________________________________________________________________________________
# inception_4a_pool_proj_bn (Batc (None, 10, 5, 64)    256         inception_4a_pool_proj[0][0]
# __________________________________________________________________________________________________
# concatenate_31 (Concatenate)    (None, 10, 5, 512)   0           inception_4a_1x1_bn[0][0]
#                                                                  inception_4a_3x3_bn[0][0]
#                                                                  inception_4a_5x5_bn[0][0]
#                                                                  inception_4a_pool_proj_bn[0][0]
# __________________________________________________________________________________________________
# inception_4b_3x3_reduce (Conv2D (None, 10, 5, 112)   57456       concatenate_31[0][0]
# __________________________________________________________________________________________________
# inception_4b5x5_reduce (Conv2D) (None, 10, 5, 24)    12312       concatenate_31[0][0]
# __________________________________________________________________________________________________
# inception_4b_3x3_reduce_bn (Bat (None, 10, 5, 112)   448         inception_4b_3x3_reduce[0][0]
# __________________________________________________________________________________________________
# inception_4b5x5_reduce_bn (Batc (None, 10, 5, 24)    96          inception_4b5x5_reduce[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_46 (MaxPooling2D) (None, 10, 5, 512)   0           concatenate_31[0][0]
# __________________________________________________________________________________________________
# inception_4b_1x1 (Conv2D)       (None, 10, 5, 160)   82080       concatenate_31[0][0]
# __________________________________________________________________________________________________
# inception_4b_3x3 (Conv2D)       (None, 10, 5, 224)   226016      inception_4b_3x3_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_4b_5x5 (Conv2D)       (None, 10, 5, 64)    38464       inception_4b5x5_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_4b_pool_proj (Conv2D) (None, 10, 5, 64)    32832       max_pooling2d_46[0][0]
# __________________________________________________________________________________________________
# inception_4b_1x1_bn (BatchNorma (None, 10, 5, 160)   640         inception_4b_1x1[0][0]
# __________________________________________________________________________________________________
# inception_4b_3x3_bn (BatchNorma (None, 10, 5, 224)   896         inception_4b_3x3[0][0]
# __________________________________________________________________________________________________
# inception_4b_5x5_bn (BatchNorma (None, 10, 5, 64)    256         inception_4b_5x5[0][0]
# __________________________________________________________________________________________________
# inception_4b_pool_proj_bn (Batc (None, 10, 5, 64)    256         inception_4b_pool_proj[0][0]
# __________________________________________________________________________________________________
# concatenate_32 (Concatenate)    (None, 10, 5, 512)   0           inception_4b_1x1_bn[0][0]
#                                                                  inception_4b_3x3_bn[0][0]
#                                                                  inception_4b_5x5_bn[0][0]
#                                                                  inception_4b_pool_proj_bn[0][0]
# __________________________________________________________________________________________________
# inception_4c_3x3_reduce (Conv2D (None, 10, 5, 128)   65664       concatenate_32[0][0]
# __________________________________________________________________________________________________
# inception_4c5x5_reduce (Conv2D) (None, 10, 5, 24)    12312       concatenate_32[0][0]
# __________________________________________________________________________________________________
# inception_4c_3x3_reduce_bn (Bat (None, 10, 5, 128)   512         inception_4c_3x3_reduce[0][0]
# __________________________________________________________________________________________________
# inception_4c5x5_reduce_bn (Batc (None, 10, 5, 24)    96          inception_4c5x5_reduce[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_47 (MaxPooling2D) (None, 10, 5, 512)   0           concatenate_32[0][0]
# __________________________________________________________________________________________________
# inception_4c_1x1 (Conv2D)       (None, 10, 5, 128)   65664       concatenate_32[0][0]
# __________________________________________________________________________________________________
# inception_4c_3x3 (Conv2D)       (None, 10, 5, 256)   295168      inception_4c_3x3_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_4c_5x5 (Conv2D)       (None, 10, 5, 64)    38464       inception_4c5x5_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_4c_pool_proj (Conv2D) (None, 10, 5, 64)    32832       max_pooling2d_47[0][0]
# __________________________________________________________________________________________________
# inception_4c_1x1_bn (BatchNorma (None, 10, 5, 128)   512         inception_4c_1x1[0][0]
# __________________________________________________________________________________________________
# inception_4c_3x3_bn (BatchNorma (None, 10, 5, 256)   1024        inception_4c_3x3[0][0]
# __________________________________________________________________________________________________
# inception_4c_5x5_bn (BatchNorma (None, 10, 5, 64)    256         inception_4c_5x5[0][0]
# __________________________________________________________________________________________________
# inception_4c_pool_proj_bn (Batc (None, 10, 5, 64)    256         inception_4c_pool_proj[0][0]
# __________________________________________________________________________________________________
# concatenate_33 (Concatenate)    (None, 10, 5, 512)   0           inception_4c_1x1_bn[0][0]
#                                                                  inception_4c_3x3_bn[0][0]
#                                                                  inception_4c_5x5_bn[0][0]
#                                                                  inception_4c_pool_proj_bn[0][0]
# __________________________________________________________________________________________________
# inception_4d_3x3_reduce (Conv2D (None, 10, 5, 144)   73872       concatenate_33[0][0]
# __________________________________________________________________________________________________
# inception_4d5x5_reduce (Conv2D) (None, 10, 5, 32)    16416       concatenate_33[0][0]
# __________________________________________________________________________________________________
# inception_4d_3x3_reduce_bn (Bat (None, 10, 5, 144)   576         inception_4d_3x3_reduce[0][0]
# __________________________________________________________________________________________________
# inception_4d5x5_reduce_bn (Batc (None, 10, 5, 32)    128         inception_4d5x5_reduce[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_48 (MaxPooling2D) (None, 10, 5, 512)   0           concatenate_33[0][0]
# __________________________________________________________________________________________________
# inception_4d_1x1 (Conv2D)       (None, 10, 5, 112)   57456       concatenate_33[0][0]
# __________________________________________________________________________________________________
# inception_4d_3x3 (Conv2D)       (None, 10, 5, 288)   373536      inception_4d_3x3_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_4d_5x5 (Conv2D)       (None, 10, 5, 64)    51264       inception_4d5x5_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_4d_pool_proj (Conv2D) (None, 10, 5, 64)    32832       max_pooling2d_48[0][0]
# __________________________________________________________________________________________________
# inception_4d_1x1_bn (BatchNorma (None, 10, 5, 112)   448         inception_4d_1x1[0][0]
# __________________________________________________________________________________________________
# inception_4d_3x3_bn (BatchNorma (None, 10, 5, 288)   1152        inception_4d_3x3[0][0]
# __________________________________________________________________________________________________
# inception_4d_5x5_bn (BatchNorma (None, 10, 5, 64)    256         inception_4d_5x5[0][0]
# __________________________________________________________________________________________________
# inception_4d_pool_proj_bn (Batc (None, 10, 5, 64)    256         inception_4d_pool_proj[0][0]
# __________________________________________________________________________________________________
# concatenate_34 (Concatenate)    (None, 10, 5, 528)   0           inception_4d_1x1_bn[0][0]
#                                                                  inception_4d_3x3_bn[0][0]
#                                                                  inception_4d_5x5_bn[0][0]
#                                                                  inception_4d_pool_proj_bn[0][0]
# __________________________________________________________________________________________________
# inception_4e_3x3_reduce (Conv2D (None, 10, 5, 160)   84640       concatenate_34[0][0]
# __________________________________________________________________________________________________
# inception_4e5x5_reduce (Conv2D) (None, 10, 5, 32)    16928       concatenate_34[0][0]
# __________________________________________________________________________________________________
# inception_4e_3x3_reduce_bn (Bat (None, 10, 5, 160)   640         inception_4e_3x3_reduce[0][0]
# __________________________________________________________________________________________________
# inception_4e5x5_reduce_bn (Batc (None, 10, 5, 32)    128         inception_4e5x5_reduce[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_49 (MaxPooling2D) (None, 10, 5, 528)   0           concatenate_34[0][0]
# __________________________________________________________________________________________________
# inception_4e_1x1 (Conv2D)       (None, 10, 5, 256)   135424      concatenate_34[0][0]
# __________________________________________________________________________________________________
# inception_4e_3x3 (Conv2D)       (None, 10, 5, 320)   461120      inception_4e_3x3_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_4e_5x5 (Conv2D)       (None, 10, 5, 128)   102528      inception_4e5x5_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_4e_pool_proj (Conv2D) (None, 10, 5, 128)   67712       max_pooling2d_49[0][0]
# __________________________________________________________________________________________________
# inception_4e_1x1_bn (BatchNorma (None, 10, 5, 256)   1024        inception_4e_1x1[0][0]
# __________________________________________________________________________________________________
# inception_4e_3x3_bn (BatchNorma (None, 10, 5, 320)   1280        inception_4e_3x3[0][0]
# __________________________________________________________________________________________________
# inception_4e_5x5_bn (BatchNorma (None, 10, 5, 128)   512         inception_4e_5x5[0][0]
# __________________________________________________________________________________________________
# inception_4e_pool_proj_bn (Batc (None, 10, 5, 128)   512         inception_4e_pool_proj[0][0]
# __________________________________________________________________________________________________
# concatenate_35 (Concatenate)    (None, 10, 5, 832)   0           inception_4e_1x1_bn[0][0]
#                                                                  inception_4e_3x3_bn[0][0]
#                                                                  inception_4e_5x5_bn[0][0]
#                                                                  inception_4e_pool_proj_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_50 (MaxPooling2D) (None, 5, 3, 832)    0           concatenate_35[0][0]
# __________________________________________________________________________________________________
# inception_5a_3x3_reduce (Conv2D (None, 5, 3, 160)    133280      max_pooling2d_50[0][0]
# __________________________________________________________________________________________________
# inception_5a5x5_reduce (Conv2D) (None, 5, 3, 32)     26656       max_pooling2d_50[0][0]
# __________________________________________________________________________________________________
# inception_5a_3x3_reduce_bn (Bat (None, 5, 3, 160)    640         inception_5a_3x3_reduce[0][0]
# __________________________________________________________________________________________________
# inception_5a5x5_reduce_bn (Batc (None, 5, 3, 32)     128         inception_5a5x5_reduce[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_51 (MaxPooling2D) (None, 5, 3, 832)    0           max_pooling2d_50[0][0]
# __________________________________________________________________________________________________
# inception_5a_1x1 (Conv2D)       (None, 5, 3, 256)    213248      max_pooling2d_50[0][0]
# __________________________________________________________________________________________________
# inception_5a_3x3 (Conv2D)       (None, 5, 3, 320)    461120      inception_5a_3x3_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_5a_5x5 (Conv2D)       (None, 5, 3, 128)    102528      inception_5a5x5_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_5a_pool_proj (Conv2D) (None, 5, 3, 128)    106624      max_pooling2d_51[0][0]
# __________________________________________________________________________________________________
# inception_5a_1x1_bn (BatchNorma (None, 5, 3, 256)    1024        inception_5a_1x1[0][0]
# __________________________________________________________________________________________________
# inception_5a_3x3_bn (BatchNorma (None, 5, 3, 320)    1280        inception_5a_3x3[0][0]
# __________________________________________________________________________________________________
# inception_5a_5x5_bn (BatchNorma (None, 5, 3, 128)    512         inception_5a_5x5[0][0]
# __________________________________________________________________________________________________
# inception_5a_pool_proj_bn (Batc (None, 5, 3, 128)    512         inception_5a_pool_proj[0][0]
# __________________________________________________________________________________________________
# concatenate_36 (Concatenate)    (None, 5, 3, 832)    0           inception_5a_1x1_bn[0][0]
#                                                                  inception_5a_3x3_bn[0][0]
#                                                                  inception_5a_5x5_bn[0][0]
#                                                                  inception_5a_pool_proj_bn[0][0]
# __________________________________________________________________________________________________
# inception_5b_3x3_reduce (Conv2D (None, 5, 3, 192)    159936      concatenate_36[0][0]
# __________________________________________________________________________________________________
# inception_5b5x5_reduce (Conv2D) (None, 5, 3, 48)     39984       concatenate_36[0][0]
# __________________________________________________________________________________________________
# inception_5b_3x3_reduce_bn (Bat (None, 5, 3, 192)    768         inception_5b_3x3_reduce[0][0]
# __________________________________________________________________________________________________
# inception_5b5x5_reduce_bn (Batc (None, 5, 3, 48)     192         inception_5b5x5_reduce[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_52 (MaxPooling2D) (None, 5, 3, 832)    0           concatenate_36[0][0]
# __________________________________________________________________________________________________
# inception_5b_1x1 (Conv2D)       (None, 5, 3, 384)    319872      concatenate_36[0][0]
# __________________________________________________________________________________________________
# inception_5b_3x3 (Conv2D)       (None, 5, 3, 384)    663936      inception_5b_3x3_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_5b_5x5 (Conv2D)       (None, 5, 3, 128)    153728      inception_5b5x5_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_5b_pool_proj (Conv2D) (None, 5, 3, 128)    106624      max_pooling2d_52[0][0]
# __________________________________________________________________________________________________
# conv1_e (Conv2D)                (None, 10, 5, 512)   2359808     concatenate_31[0][0]
# __________________________________________________________________________________________________
# conv2_e (Conv2D)                (None, 10, 5, 512)   2433536     concatenate_34[0][0]
# __________________________________________________________________________________________________
# inception_5b_1x1_bn (BatchNorma (None, 5, 3, 384)    1536        inception_5b_1x1[0][0]
# __________________________________________________________________________________________________
# inception_5b_3x3_bn (BatchNorma (None, 5, 3, 384)    1536        inception_5b_3x3[0][0]
# __________________________________________________________________________________________________
# inception_5b_5x5_bn (BatchNorma (None, 5, 3, 128)    512         inception_5b_5x5[0][0]
# __________________________________________________________________________________________________
# inception_5b_pool_proj_bn (Batc (None, 5, 3, 128)    512         inception_5b_pool_proj[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_6 (Glo (None, 512)          0           conv1_e[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_7 (Glo (None, 512)          0           conv2_e[0][0]
# __________________________________________________________________________________________________
# concatenate_37 (Concatenate)    (None, 5, 3, 1024)   0           inception_5b_1x1_bn[0][0]
#                                                                  inception_5b_3x3_bn[0][0]
#                                                                  inception_5b_5x5_bn[0][0]
#                                                                  inception_5b_pool_proj_bn[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 512)          262656      global_average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 512)          262656      global_average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# conv3_e (Conv2D)                (None, 5, 3, 1024)   9438208     concatenate_37[0][0]
# __________________________________________________________________________________________________
# low (Dense)                     (None, 4)            2052        dense_5[0][0]
# __________________________________________________________________________________________________
# middle (Dense)                  (None, 43)           22059       dense_6[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_8 (Glo (None, 1024)         0           conv3_e[0][0]
# __________________________________________________________________________________________________
# concatenate_38 (Concatenate)    (None, 47)           0           low[0][0]
#                                                                  middle[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 1024)         1049600     global_average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# high_cond (Dense)               (None, 14)           672         concatenate_38[0][0]
# __________________________________________________________________________________________________
# high (Dense)                    (None, 14)           14350       dense_7[0][0]
# __________________________________________________________________________________________________
# high_post (Lambda)              (None, 14)           0           high_cond[0][0]
#                                                                  high[0][0]
# __________________________________________________________________________________________________
# concatenate_39 (Concatenate)    (None, 61)           0           low[0][0]
#                                                                  middle[0][0]
#                                                                  high_post[0][0]
# ==================================================================================================
# Total params: 21,843,853
# Trainable params: 21,829,421
# Non-trainable params: 14,432
# __________________________________________________________________________________________________

# %%
weights = model_hr.get_layer('high_cond').get_weights()
print(weights)
# Out:
# [array([[-8.88814926e-01,  9.26568091e-01, -3.99266750e-01,
#         -1.18520534e+00, -7.84428954e-01, -9.59272921e-01,
#         -4.04158175e-01,  4.37925495e-02, -1.78039014e+00,
#         -1.08930683e+00, -1.34683883e+00, -7.58984387e-01,
#         -6.96536377e-02, -8.45460117e-01],
#        [-6.29673526e-02,  1.23107873e-01,  8.46137777e-02,
#         -4.45429564e-01, -1.38495322e-02, -4.11410451e-01,
#          1.96292683e-01,  5.60126118e-02, -8.49808395e-01,
#         -1.72819763e-01,  9.00157765e-02, -2.39601597e-01,
#          4.01569909e-04, -2.07700357e-01],
#        [ 1.30305135e+00,  9.64093089e-01, -4.93524551e-01,
#         -7.32405365e-01, -7.69868433e-01,  5.47400773e-01,
#          1.08024693e+00,  2.44109586e-01, -3.47159833e-01,
#         -4.60683763e-01, -5.53538382e-01, -6.28140926e-01,
#         -5.46820760e-01, -7.38448024e-01],
#        [ 3.21376830e-01,  6.36975288e-01,  4.29113805e-02,
#         -2.55443633e-01, -1.06662178e+00,  1.04670072e+00,
#          6.11878395e-01,  3.08323771e-01, -2.38375497e+00,
#         -4.85986024e-01, -3.69731724e-01, -2.95069814e-01,
#          7.50266373e-01, -1.52572060e+00],
#        [-1.29230693e-01,  9.95108008e-01, -4.92467165e-01,
#        [ 1.52287349e-01,  6.75213993e-01,  6.31420612e-01,
#          3.29218209e-01,  9.64150429e-01, -2.45483208e+00,
#          1.87063730e+00,  1.23003936e+00,  1.12729275e+00,
#          6.92360461e-01,  5.23987114e-01, -5.27835965e-01,
#          9.23401475e-01,  6.57014608e-01],
#        [ 4.71787378e-02,  1.24706769e+00,  4.60908353e-01,
#          7.47299671e-01,  6.70876801e-01, -7.37652838e-01,
#         -4.67582554e-01,  1.68934035e+00, -6.50778055e-01,
#         -4.54554826e-01, -9.71059859e-01, -6.24509215e-01,
#          7.98309684e-01, -2.26163730e-01],
#        [-1.18728846e-01,  9.41287398e-01,  8.99534702e-01,
#          1.45786166e-01,  3.51805747e-01,  9.29403380e-02,
#          1.30258489e+00,  8.04040968e-01,  9.58667338e-01,
#          9.05718446e-01,  7.10186124e-01,  1.60937414e-01,
#         -1.81175679e-01,  9.11701620e-01],
#        [-5.68890035e-01,  1.16767371e+00, -6.04425259e-02,
#          3.09938908e-01, -6.13161802e-01, -6.19614303e-01,
#         -3.86949271e-01, -1.08469880e+00, -5.65307438e-01,
#         -4.67731535e-01, -7.50758410e-01, -4.92871553e-01,
#          1.45465314e-01, -5.42557001e-01]], dtype=float32), array([ 0.3132152 ,  0.94911456,  1.140868  ,  0.6120253 ,  0.4033546 ,
#         0.43252644,  0.88343036,  1.0044672 ,  0.7287439 ,  0.5713629 ,
#         0.6764705 , -0.23286657,  0.49859262,  0.41973326], dtype=float32)]

# %%
print(weights[0].shape)
# Out:
# (47, 14)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

plt.subplots(figsize=(9, 9))
sns.heatmap(weights[0], cmap="Blues", square=True, xticklabels = ['personalLess15', 'personalLess30', 'personalLess45', 'personalLess60', 'personalLarger60', 'lowerBodyCapri', 'lowerBodyCasual', 'upperBodyCasual', 'personalFemale', 'lowerBodyFormal', 'upperBodyFormal', 'lowerBodyPlaid', 'personalMale', 'upperBodyPlaid'], yticklabels = ['upperBodyLogo', 'lowerBodyThinStripes', 'upperBodyThinStripes', 'upperBodyThickStripes', 'accessoryHeadphone', 'carryingBabyBuggy', 'carryingBackpack', 'hairBald', 'footwearBoots', 'carryingOther', 'carryingShoppingTro', 'carryingUmbrella', 'carryingFolder', 'accessoryHairBand', 'accessoryHat', 'lowerBodyHotPants', 'upperBodyJacket', 'lowerBodyJeans', 'accessoryKerchief', 'footwearLeatherShoes', 'hairLong', 'lowerBodyLongSkirt', 'upperBodyLongSleeve', 'carryingLuggageCase', 'carryingMessengerBag', 'accessoryMuffler', 'accessoryNothing', 'carryingNothing', 'upperBodyNoSleeve', 'carryingPlasticBags', 'footwearSandals', 'footwearShoes', 'hairShort', 'lowerBodyShorts', 'upperBodyShortSleeve', 'lowerBodyShortSkirt', 'footwearSneakers', 'footwearStocking', 'upperBodySuit', 'carryingSuitcase', 'lowerBodySuits', 'accessorySunglasses', 'upperBodySweater', 'lowerBodyTrousers', 'upperBodyTshirt', 'upperBodyOther', 'upperBodyVNeck'])
plt.show()
