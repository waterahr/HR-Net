# %%
attributes_list = ['upperBodyLogo', 'lowerBodyThinStripes', 'upperBodyThinStripes', 'upperBodyThickStripes', 'accessoryHeadphone', 'carryingBabyBuggy', 'carryingBackpack', 'hairBald', 'footwearBoots', 'carryingOther', 'carryingShoppingTro', 'carryingUmbrella', 'carryingFolder', 'accessoryHairBand', 'accessoryHat', 'lowerBodyHotPants', 'upperBodyJacket', 'lowerBodyJeans', 'accessoryKerchief', 'footwearLeatherShoes', 'hairLong', 'lowerBodyLongSkirt', 'upperBodyLongSleeve', 'carryingLuggageCase', 'carryingMessengerBag', 'accessoryMuffler', 'accessoryNothing', 'carryingNothing', 'upperBodyNoSleeve', 'carryingPlasticBags', 'footwearSandals', 'footwearShoes', 'hairShort', 'lowerBodyShorts', 'upperBodyShortSleeve', 'lowerBodyShortSkirt', 'footwearSneakers', 'footwearStocking', 'upperBodySuit', 'carryingSuitcase', 'lowerBodySuits', 'accessorySunglasses', 'upperBodySweater', 'lowerBodyTrousers', 'upperBodyTshirt', 'upperBodyOther', 'upperBodyVNeck', 'personalLess15', 'personalLess30', 'personalLess45', 'personalLess60', 'personalLarger60', 'lowerBodyCapri', 'lowerBodyCasual', 'upperBodyCasual', 'personalFemale', 'lowerBodyFormal', 'upperBodyFormal', 'lowerBodyPlaid', 'personalMale', 'upperBodyPlaid']
print(attributes_list)
# Out:
# ['upperBodyLogo', 'lowerBodyThinStripes', 'upperBodyThinStripes', 'upperBodyThickStripes', 'accessoryHeadphone', 'carryingBabyBuggy', 'carryingBackpack', 'hairBald', 'footwearBoots', 'carryingOther', 'carryingShoppingTro', 'carryingUmbrella', 'carryingFolder', 'accessoryHairBand', 'accessoryHat', 'lowerBodyHotPants', 'upperBodyJacket', 'lowerBodyJeans', 'accessoryKerchief', 'footwearLeatherShoes', 'hairLong', 'lowerBodyLongSkirt', 'upperBodyLongSleeve', 'carryingLuggageCase', 'carryingMessengerBag', 'accessoryMuffler', 'accessoryNothing', 'carryingNothing', 'upperBodyNoSleeve', 'carryingPlasticBags', 'footwearSandals', 'footwearShoes', 'hairShort', 'lowerBodyShorts', 'upperBodyShortSleeve', 'lowerBodyShortSkirt', 'footwearSneakers', 'footwearStocking', 'upperBodySuit', 'carryingSuitcase', 'lowerBodySuits', 'accessorySunglasses', 'upperBodySweater', 'lowerBodyTrousers', 'upperBodyTshirt', 'upperBodyOther', 'upperBodyVNeck', 'personalLess15', 'personalLess30', 'personalLess45', 'personalLess60', 'personalLarger60', 'lowerBodyCapri', 'lowerBodyCasual', 'upperBodyCasual', 'personalFemale', 'lowerBodyFormal', 'upperBodyFormal', 'lowerBodyPlaid', 'personalMale', 'upperBodyPlaid']

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = ""
from keras.applications import InceptionV3
from keras.applications.inception_v3 import preprocess_input
from keras.preprocessing import image
from keras.models import Model
from keras.applications.imagenet_utils import decode_predictions
import numpy as np
import cv2
from cv2 import *
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy as sp
from scipy.misc import toimage
import sys
sys.path.append("..")
from src.network.GoogleLenet import GoogLeNet
from src.network.hiarBayesGoogLenet_gap import hiarBayesGoogLeNet
from src.network.partGoogLeNet import partGoogLeNet

low_level = [27, 32, 50, 56]#, 61, 62, 63, 64
mid_level = [0, 6, 7, 8, 9, 11, 12, 13, 17, 20, 21, 22, 23, 24, 25, 26, 28, 29, 30, 33, 35, 36, 37, 38, 39, 41, 42, 43, 44, 45, 46, 47, 48, 49, 51, 52, 53, 54, 55, 57, 58, 59, 60]
high_level = [1, 2, 3, 4, 5, 10, 14, 15, 16, 18, 19, 31, 34, 40]

head_level = [0,8,20,21,25,28,36,37,44,54]
upperbody_level = [7,15,17,19,23,27,30,39,40,46,50,51,55,56,58,59,60]
lowerbody_level = [6,10,11,12,13,14,18,22,24,29,31,32,33,35,38,41,45,47,52,53,57]
foot_level = [9,26,42,43,48,49]
global_level = [1,2,3,4,5,16,34]

image_width = 75
image_height = 160
#model_h = hiarGoogLeNet.build(image_height, image_width, 3, [len(low_level), len(mid_level), len(high_level)])
#model_h.load_weights("/home/anhaoran/codes/pedestrian_attibutes_wpal/models/imagenet_models/hiarGoogLeNet_RAP/binary51_epoch50_valloss0.21.hdf5")
#model_g = GoogLeNet.build(image_height, image_width, 3, 51)
#model_g.load_weights("../models/imagenet_models/GoogLeNet_RAP/binary51_epoch50_valloss0.54.hdf5")
model_gh = hiarBayesGoogLeNet.build(image_height, image_width, 3, [len(low_level), len(mid_level), len(high_level)])
model_gh.load_weights("../models/imagenet_models/hiarBayesGoogLeNet_PETA/binary61_gap&dense_final500iter_model.h5")
model_gh.summary()
model_p = partGoogLeNet.build(image_height, image_width, 3, [head_level, upperbody_level, lowerbody_level, foot_level, global_level])
model_p.load_weights("../models/imagenet_models/partGoogLeNet_PETA/binary61__final50iter_model.h5")
model_p.summary()
# Out:
# Using TensorFlow backend.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 160, 75, 3)   0
# __________________________________________________________________________________________________
# conv1_7x7_s2 (Conv2D)           (None, 80, 38, 64)   9472        input_1[0][0]
# __________________________________________________________________________________________________
# conv1_7x7_s2_bn (BatchNormaliza (None, 80, 38, 64)   256         conv1_7x7_s2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 40, 19, 64)   0           conv1_7x7_s2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_3x3 (Conv2D)              (None, 40, 19, 192)  110784      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2_3x3_bn (BatchNormalizatio (None, 40, 19, 192)  768         conv2_3x3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 20, 10, 192)  0           conv2_3x3_bn[0][0]
# __________________________________________________________________________________________________
# inception_3a_3x3_reduce (Conv2D (None, 20, 10, 96)   18528       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# inception_3a5x5_reduce (Conv2D) (None, 20, 10, 16)   3088        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# inception_3a_3x3_reduce_bn (Bat (None, 20, 10, 96)   384         inception_3a_3x3_reduce[0][0]
# __________________________________________________________________________________________________
# inception_3a5x5_reduce_bn (Batc (None, 20, 10, 16)   64          inception_3a5x5_reduce[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 20, 10, 192)  0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# inception_3a_1x1 (Conv2D)       (None, 20, 10, 64)   12352       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# inception_3a_3x3 (Conv2D)       (None, 20, 10, 128)  110720      inception_3a_3x3_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_3a_5x5 (Conv2D)       (None, 20, 10, 32)   12832       inception_3a5x5_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_3a_pool_proj (Conv2D) (None, 20, 10, 32)   6176        max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# inception_3a_1x1_bn (BatchNorma (None, 20, 10, 64)   256         inception_3a_1x1[0][0]
# __________________________________________________________________________________________________
# inception_3a_3x3_bn (BatchNorma (None, 20, 10, 128)  512         inception_3a_3x3[0][0]
# __________________________________________________________________________________________________
# inception_3a_5x5_bn (BatchNorma (None, 20, 10, 32)   128         inception_3a_5x5[0][0]
# __________________________________________________________________________________________________
# inception_3a_pool_proj_bn (Batc (None, 20, 10, 32)   128         inception_3a_pool_proj[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 20, 10, 256)  0           inception_3a_1x1_bn[0][0]
#                                                                  inception_3a_3x3_bn[0][0]
#                                                                  inception_3a_5x5_bn[0][0]
#                                                                  inception_3a_pool_proj_bn[0][0]
# __________________________________________________________________________________________________
# inception_3b_3x3_reduce (Conv2D (None, 20, 10, 128)  32896       concatenate_1[0][0]
# __________________________________________________________________________________________________
# inception_3b5x5_reduce (Conv2D) (None, 20, 10, 32)   8224        concatenate_1[0][0]
# __________________________________________________________________________________________________
# inception_3b_3x3_reduce_bn (Bat (None, 20, 10, 128)  512         inception_3b_3x3_reduce[0][0]
# __________________________________________________________________________________________________
# inception_3b5x5_reduce_bn (Batc (None, 20, 10, 32)   128         inception_3b5x5_reduce[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 20, 10, 256)  0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# inception_3b_1x1 (Conv2D)       (None, 20, 10, 128)  32896       concatenate_1[0][0]
# __________________________________________________________________________________________________
# inception_3b_3x3 (Conv2D)       (None, 20, 10, 192)  221376      inception_3b_3x3_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_3b_5x5 (Conv2D)       (None, 20, 10, 96)   76896       inception_3b5x5_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_3b_pool_proj (Conv2D) (None, 20, 10, 64)   16448       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# inception_3b_1x1_bn (BatchNorma (None, 20, 10, 128)  512         inception_3b_1x1[0][0]
# __________________________________________________________________________________________________
# inception_3b_3x3_bn (BatchNorma (None, 20, 10, 192)  768         inception_3b_3x3[0][0]
# __________________________________________________________________________________________________
# inception_3b_5x5_bn (BatchNorma (None, 20, 10, 96)   384         inception_3b_5x5[0][0]
# __________________________________________________________________________________________________
# inception_3b_pool_proj_bn (Batc (None, 20, 10, 64)   256         inception_3b_pool_proj[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 20, 10, 480)  0           inception_3b_1x1_bn[0][0]
#                                                                  inception_3b_3x3_bn[0][0]
#                                                                  inception_3b_5x5_bn[0][0]
#                                                                  inception_3b_pool_proj_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 10, 5, 480)   0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# inception_4a_3x3_reduce (Conv2D (None, 10, 5, 96)    46176       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# inception_4a5x5_reduce (Conv2D) (None, 10, 5, 16)    7696        max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# inception_4a_3x3_reduce_bn (Bat (None, 10, 5, 96)    384         inception_4a_3x3_reduce[0][0]
# __________________________________________________________________________________________________
# inception_4a5x5_reduce_bn (Batc (None, 10, 5, 16)    64          inception_4a5x5_reduce[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 10, 5, 480)   0           max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# inception_4a_1x1 (Conv2D)       (None, 10, 5, 192)   92352       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# inception_4a_3x3 (Conv2D)       (None, 10, 5, 208)   179920      inception_4a_3x3_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_4a_5x5 (Conv2D)       (None, 10, 5, 48)    19248       inception_4a5x5_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_4a_pool_proj (Conv2D) (None, 10, 5, 64)    30784       max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# inception_4a_1x1_bn (BatchNorma (None, 10, 5, 192)   768         inception_4a_1x1[0][0]
# __________________________________________________________________________________________________
# inception_4a_3x3_bn (BatchNorma (None, 10, 5, 208)   832         inception_4a_3x3[0][0]
# __________________________________________________________________________________________________
# inception_4a_5x5_bn (BatchNorma (None, 10, 5, 48)    192         inception_4a_5x5[0][0]
# __________________________________________________________________________________________________
# inception_4a_pool_proj_bn (Batc (None, 10, 5, 64)    256         inception_4a_pool_proj[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 10, 5, 512)   0           inception_4a_1x1_bn[0][0]
#                                                                  inception_4a_3x3_bn[0][0]
#                                                                  inception_4a_5x5_bn[0][0]
#                                                                  inception_4a_pool_proj_bn[0][0]
# __________________________________________________________________________________________________
# inception_4b_3x3_reduce (Conv2D (None, 10, 5, 112)   57456       concatenate_3[0][0]
# __________________________________________________________________________________________________
# inception_4b5x5_reduce (Conv2D) (None, 10, 5, 24)    12312       concatenate_3[0][0]
# __________________________________________________________________________________________________
# inception_4b_3x3_reduce_bn (Bat (None, 10, 5, 112)   448         inception_4b_3x3_reduce[0][0]
# __________________________________________________________________________________________________
# inception_4b5x5_reduce_bn (Batc (None, 10, 5, 24)    96          inception_4b5x5_reduce[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 10, 5, 512)   0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# inception_4b_1x1 (Conv2D)       (None, 10, 5, 160)   82080       concatenate_3[0][0]
# __________________________________________________________________________________________________
# inception_4b_3x3 (Conv2D)       (None, 10, 5, 224)   226016      inception_4b_3x3_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_4b_5x5 (Conv2D)       (None, 10, 5, 64)    38464       inception_4b5x5_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_4b_pool_proj (Conv2D) (None, 10, 5, 64)    32832       max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# inception_4b_1x1_bn (BatchNorma (None, 10, 5, 160)   640         inception_4b_1x1[0][0]
# __________________________________________________________________________________________________
# inception_4b_3x3_bn (BatchNorma (None, 10, 5, 224)   896         inception_4b_3x3[0][0]
# __________________________________________________________________________________________________
# inception_4b_5x5_bn (BatchNorma (None, 10, 5, 64)    256         inception_4b_5x5[0][0]
# __________________________________________________________________________________________________
# inception_4b_pool_proj_bn (Batc (None, 10, 5, 64)    256         inception_4b_pool_proj[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 10, 5, 512)   0           inception_4b_1x1_bn[0][0]
#                                                                  inception_4b_3x3_bn[0][0]
#                                                                  inception_4b_5x5_bn[0][0]
#                                                                  inception_4b_pool_proj_bn[0][0]
# __________________________________________________________________________________________________
# inception_4c_3x3_reduce (Conv2D (None, 10, 5, 128)   65664       concatenate_4[0][0]
# __________________________________________________________________________________________________
# inception_4c5x5_reduce (Conv2D) (None, 10, 5, 24)    12312       concatenate_4[0][0]
# __________________________________________________________________________________________________
# inception_4c_3x3_reduce_bn (Bat (None, 10, 5, 128)   512         inception_4c_3x3_reduce[0][0]
# __________________________________________________________________________________________________
# inception_4c5x5_reduce_bn (Batc (None, 10, 5, 24)    96          inception_4c5x5_reduce[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 10, 5, 512)   0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# inception_4c_1x1 (Conv2D)       (None, 10, 5, 128)   65664       concatenate_4[0][0]
# __________________________________________________________________________________________________
# inception_4c_3x3 (Conv2D)       (None, 10, 5, 256)   295168      inception_4c_3x3_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_4c_5x5 (Conv2D)       (None, 10, 5, 64)    38464       inception_4c5x5_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_4c_pool_proj (Conv2D) (None, 10, 5, 64)    32832       max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# inception_4c_1x1_bn (BatchNorma (None, 10, 5, 128)   512         inception_4c_1x1[0][0]
# __________________________________________________________________________________________________
# inception_4c_3x3_bn (BatchNorma (None, 10, 5, 256)   1024        inception_4c_3x3[0][0]
# __________________________________________________________________________________________________
# inception_4c_5x5_bn (BatchNorma (None, 10, 5, 64)    256         inception_4c_5x5[0][0]
# __________________________________________________________________________________________________
# inception_4c_pool_proj_bn (Batc (None, 10, 5, 64)    256         inception_4c_pool_proj[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 10, 5, 512)   0           inception_4c_1x1_bn[0][0]
#                                                                  inception_4c_3x3_bn[0][0]
#                                                                  inception_4c_5x5_bn[0][0]
#                                                                  inception_4c_pool_proj_bn[0][0]
# __________________________________________________________________________________________________
# inception_4d_3x3_reduce (Conv2D (None, 10, 5, 144)   73872       concatenate_5[0][0]
# __________________________________________________________________________________________________
# inception_4d5x5_reduce (Conv2D) (None, 10, 5, 32)    16416       concatenate_5[0][0]
# __________________________________________________________________________________________________
# inception_4d_3x3_reduce_bn (Bat (None, 10, 5, 144)   576         inception_4d_3x3_reduce[0][0]
# __________________________________________________________________________________________________
# inception_4d5x5_reduce_bn (Batc (None, 10, 5, 32)    128         inception_4d5x5_reduce[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 10, 5, 512)   0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# inception_4d_1x1 (Conv2D)       (None, 10, 5, 112)   57456       concatenate_5[0][0]
# __________________________________________________________________________________________________
# inception_4d_3x3 (Conv2D)       (None, 10, 5, 288)   373536      inception_4d_3x3_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_4d_5x5 (Conv2D)       (None, 10, 5, 64)    51264       inception_4d5x5_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_4d_pool_proj (Conv2D) (None, 10, 5, 64)    32832       max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# inception_4d_1x1_bn (BatchNorma (None, 10, 5, 112)   448         inception_4d_1x1[0][0]
# __________________________________________________________________________________________________
# inception_4d_3x3_bn (BatchNorma (None, 10, 5, 288)   1152        inception_4d_3x3[0][0]
# __________________________________________________________________________________________________
# inception_4d_5x5_bn (BatchNorma (None, 10, 5, 64)    256         inception_4d_5x5[0][0]
# __________________________________________________________________________________________________
# inception_4d_pool_proj_bn (Batc (None, 10, 5, 64)    256         inception_4d_pool_proj[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 10, 5, 528)   0           inception_4d_1x1_bn[0][0]
#                                                                  inception_4d_3x3_bn[0][0]
#                                                                  inception_4d_5x5_bn[0][0]
#                                                                  inception_4d_pool_proj_bn[0][0]
# __________________________________________________________________________________________________
# inception_4e_3x3_reduce (Conv2D (None, 10, 5, 160)   84640       concatenate_6[0][0]
# __________________________________________________________________________________________________
# inception_4e5x5_reduce (Conv2D) (None, 10, 5, 32)    16928       concatenate_6[0][0]
# __________________________________________________________________________________________________
# inception_4e_3x3_reduce_bn (Bat (None, 10, 5, 160)   640         inception_4e_3x3_reduce[0][0]
# __________________________________________________________________________________________________
# inception_4e5x5_reduce_bn (Batc (None, 10, 5, 32)    128         inception_4e5x5_reduce[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 10, 5, 528)   0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# inception_4e_1x1 (Conv2D)       (None, 10, 5, 256)   135424      concatenate_6[0][0]
# __________________________________________________________________________________________________
# inception_4e_3x3 (Conv2D)       (None, 10, 5, 320)   461120      inception_4e_3x3_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_4e_5x5 (Conv2D)       (None, 10, 5, 128)   102528      inception_4e5x5_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_4e_pool_proj (Conv2D) (None, 10, 5, 128)   67712       max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# inception_4e_1x1_bn (BatchNorma (None, 10, 5, 256)   1024        inception_4e_1x1[0][0]
# __________________________________________________________________________________________________
# inception_4e_3x3_bn (BatchNorma (None, 10, 5, 320)   1280        inception_4e_3x3[0][0]
# __________________________________________________________________________________________________
# inception_4e_5x5_bn (BatchNorma (None, 10, 5, 128)   512         inception_4e_5x5[0][0]
# __________________________________________________________________________________________________
# inception_4e_pool_proj_bn (Batc (None, 10, 5, 128)   512         inception_4e_pool_proj[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 10, 5, 832)   0           inception_4e_1x1_bn[0][0]
#                                                                  inception_4e_3x3_bn[0][0]
#                                                                  inception_4e_5x5_bn[0][0]
#                                                                  inception_4e_pool_proj_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 5, 3, 832)    0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# inception_5a_3x3_reduce (Conv2D (None, 5, 3, 160)    133280      max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# inception_5a5x5_reduce (Conv2D) (None, 5, 3, 32)     26656       max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# inception_5a_3x3_reduce_bn (Bat (None, 5, 3, 160)    640         inception_5a_3x3_reduce[0][0]
# __________________________________________________________________________________________________
# inception_5a5x5_reduce_bn (Batc (None, 5, 3, 32)     128         inception_5a5x5_reduce[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 5, 3, 832)    0           max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# inception_5a_1x1 (Conv2D)       (None, 5, 3, 256)    213248      max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# inception_5a_3x3 (Conv2D)       (None, 5, 3, 320)    461120      inception_5a_3x3_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_5a_5x5 (Conv2D)       (None, 5, 3, 128)    102528      inception_5a5x5_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_5a_pool_proj (Conv2D) (None, 5, 3, 128)    106624      max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# inception_5a_1x1_bn (BatchNorma (None, 5, 3, 256)    1024        inception_5a_1x1[0][0]
# __________________________________________________________________________________________________
# inception_5a_3x3_bn (BatchNorma (None, 5, 3, 320)    1280        inception_5a_3x3[0][0]
# __________________________________________________________________________________________________
# inception_5a_5x5_bn (BatchNorma (None, 5, 3, 128)    512         inception_5a_5x5[0][0]
# __________________________________________________________________________________________________
# inception_5a_pool_proj_bn (Batc (None, 5, 3, 128)    512         inception_5a_pool_proj[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 5, 3, 832)    0           inception_5a_1x1_bn[0][0]
#                                                                  inception_5a_3x3_bn[0][0]
#                                                                  inception_5a_5x5_bn[0][0]
#                                                                  inception_5a_pool_proj_bn[0][0]
# __________________________________________________________________________________________________
# inception_5b_3x3_reduce (Conv2D (None, 5, 3, 192)    159936      concatenate_8[0][0]
# __________________________________________________________________________________________________
# inception_5b5x5_reduce (Conv2D) (None, 5, 3, 48)     39984       concatenate_8[0][0]
# __________________________________________________________________________________________________
# inception_5b_3x3_reduce_bn (Bat (None, 5, 3, 192)    768         inception_5b_3x3_reduce[0][0]
# __________________________________________________________________________________________________
# inception_5b5x5_reduce_bn (Batc (None, 5, 3, 48)     192         inception_5b5x5_reduce[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_13 (MaxPooling2D) (None, 5, 3, 832)    0           concatenate_8[0][0]
# __________________________________________________________________________________________________
# inception_5b_1x1 (Conv2D)       (None, 5, 3, 384)    319872      concatenate_8[0][0]
# __________________________________________________________________________________________________
# inception_5b_3x3 (Conv2D)       (None, 5, 3, 384)    663936      inception_5b_3x3_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_5b_5x5 (Conv2D)       (None, 5, 3, 128)    153728      inception_5b5x5_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_5b_pool_proj (Conv2D) (None, 5, 3, 128)    106624      max_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# conv1_e (Conv2D)                (None, 10, 5, 512)   2359808     concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2_e (Conv2D)                (None, 10, 5, 512)   2433536     concatenate_6[0][0]
# __________________________________________________________________________________________________
# inception_5b_1x1_bn (BatchNorma (None, 5, 3, 384)    1536        inception_5b_1x1[0][0]
# __________________________________________________________________________________________________
# inception_5b_3x3_bn (BatchNorma (None, 5, 3, 384)    1536        inception_5b_3x3[0][0]
# __________________________________________________________________________________________________
# inception_5b_5x5_bn (BatchNorma (None, 5, 3, 128)    512         inception_5b_5x5[0][0]
# __________________________________________________________________________________________________
# inception_5b_pool_proj_bn (Batc (None, 5, 3, 128)    512         inception_5b_pool_proj[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 512)          0           conv1_e[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 512)          0           conv2_e[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 5, 3, 1024)   0           inception_5b_1x1_bn[0][0]
#                                                                  inception_5b_3x3_bn[0][0]
#                                                                  inception_5b_5x5_bn[0][0]
#                                                                  inception_5b_pool_proj_bn[0][0]
# __________________________________________________________________________________________________
# low (Dense)                     (None, 4)            2052        global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# middle (Dense)                  (None, 43)           22059       global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv3_e (Conv2D)                (None, 5, 3, 1024)   9438208     concatenate_9[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 47)           0           low[0][0]
#                                                                  middle[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_3 (Glo (None, 1024)         0           conv3_e[0][0]
# __________________________________________________________________________________________________
# high_cond (Dense)               (None, 14)           672         concatenate_10[0][0]
# __________________________________________________________________________________________________
# high (Dense)                    (None, 14)           14350       global_average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# high_post (Lambda)              (None, 14)           0           high_cond[0][0]
#                                                                  high[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 61)           0           low[0][0]
#                                                                  middle[0][0]
#                                                                  high_post[0][0]
# ==================================================================================================
# Total params: 20,268,941
# Trainable params: 20,254,509
# Non-trainable params: 14,432
# __________________________________________________________________________________________________
# -----------------
# ['accessoryHeadphone' 'hairBald' 'accessoryHairBand' 'accessoryHat'
#  'accessoryKerchief' 'hairLong' 'accessoryMuffler' 'accessoryNothing'
#  'hairShort' 'accessorySunglasses']
# -----------------
# -----------------
# ['carryingBackpack' 'upperBodyCasual' 'carryingFolder' 'upperBodyFormal'
#  'upperBodyJacket' 'upperBodyLogo' 'upperBodyLongSleeve'
#  'upperBodyNoSleeve' 'upperBodyPlaid' 'upperBodyShortSleeve'
#  'upperBodyThinStripes' 'upperBodySuit' 'upperBodySweater'
#  'upperBodyThickStripes' 'upperBodyTshirt' 'upperBodyOther'
#  'upperBodyVNeck']
# -----------------
# -----------------
# ['carryingBabyBuggy' 'lowerBodyCapri' 'carryingOther'
#  'carryingShoppingTro' 'carryingUmbrella' 'lowerBodyCasual'
#  'lowerBodyFormal' 'lowerBodyHotPants' 'lowerBodyJeans'
#  'lowerBodyLongSkirt' 'lowerBodyPlaid' 'lowerBodyThinStripes'
#  'carryingLuggageCase' 'carryingMessengerBag' 'carryingNothing'
#  'carryingPlasticBags' 'lowerBodyShorts' 'lowerBodyShortSkirt'
#  'carryingSuitcase' 'lowerBodySuits' 'lowerBodyTrousers']
# -----------------
# -----------------
# ['footwearBoots' 'footwearLeatherShoes' 'footwearSandals' 'footwearShoes'
#  'footwearSneakers' 'footwearStocking']
# -----------------
# -----------------
# ['personalLess15' 'personalLess30' 'personalLess45' 'personalLess60'
#  'personalLarger60' 'personalFemale' 'personalMale']
# -----------------
# ImageNet...
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 160, 75, 3)   0
# __________________________________________________________________________________________________
# conv1_7x7_s2 (Conv2D)           (None, 80, 38, 64)   9472        input_2[0][0]
# __________________________________________________________________________________________________
# conv1_7x7_s2_bn (BatchNormaliza (None, 80, 38, 64)   256         conv1_7x7_s2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_14 (MaxPooling2D) (None, 40, 19, 64)   0           conv1_7x7_s2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_3x3 (Conv2D)              (None, 40, 19, 192)  110784      max_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# conv2_3x3_bn (BatchNormalizatio (None, 40, 19, 192)  768         conv2_3x3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D) (None, 20, 10, 192)  0           conv2_3x3_bn[0][0]
# __________________________________________________________________________________________________
# inception_3a_3x3_reduce (Conv2D (None, 20, 10, 96)   18528       max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# inception_3a5x5_reduce (Conv2D) (None, 20, 10, 16)   3088        max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# inception_3a_3x3_reduce_bn (Bat (None, 20, 10, 96)   384         inception_3a_3x3_reduce[0][0]
# __________________________________________________________________________________________________
# inception_3a5x5_reduce_bn (Batc (None, 20, 10, 16)   64          inception_3a5x5_reduce[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_16 (MaxPooling2D) (None, 20, 10, 192)  0           max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# inception_3a_1x1 (Conv2D)       (None, 20, 10, 64)   12352       max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# inception_3a_3x3 (Conv2D)       (None, 20, 10, 128)  110720      inception_3a_3x3_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_3a_5x5 (Conv2D)       (None, 20, 10, 32)   12832       inception_3a5x5_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_3a_pool_proj (Conv2D) (None, 20, 10, 32)   6176        max_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# inception_3a_1x1_bn (BatchNorma (None, 20, 10, 64)   256         inception_3a_1x1[0][0]
# __________________________________________________________________________________________________
# inception_3a_3x3_bn (BatchNorma (None, 20, 10, 128)  512         inception_3a_3x3[0][0]
# __________________________________________________________________________________________________
# inception_3a_5x5_bn (BatchNorma (None, 20, 10, 32)   128         inception_3a_5x5[0][0]
# __________________________________________________________________________________________________
# inception_3a_pool_proj_bn (Batc (None, 20, 10, 32)   128         inception_3a_pool_proj[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 20, 10, 256)  0           inception_3a_1x1_bn[0][0]
#                                                                  inception_3a_3x3_bn[0][0]
#                                                                  inception_3a_5x5_bn[0][0]
#                                                                  inception_3a_pool_proj_bn[0][0]
# __________________________________________________________________________________________________
# inception_3b_3x3_reduce (Conv2D (None, 20, 10, 128)  32896       concatenate_12[0][0]
# __________________________________________________________________________________________________
# inception_3b5x5_reduce (Conv2D) (None, 20, 10, 32)   8224        concatenate_12[0][0]
# __________________________________________________________________________________________________
# inception_3b_3x3_reduce_bn (Bat (None, 20, 10, 128)  512         inception_3b_3x3_reduce[0][0]
# __________________________________________________________________________________________________
# inception_3b5x5_reduce_bn (Batc (None, 20, 10, 32)   128         inception_3b5x5_reduce[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_17 (MaxPooling2D) (None, 20, 10, 256)  0           concatenate_12[0][0]
# __________________________________________________________________________________________________
# inception_3b_1x1 (Conv2D)       (None, 20, 10, 128)  32896       concatenate_12[0][0]
# __________________________________________________________________________________________________
# inception_3b_3x3 (Conv2D)       (None, 20, 10, 192)  221376      inception_3b_3x3_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_3b_5x5 (Conv2D)       (None, 20, 10, 96)   76896       inception_3b5x5_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_3b_pool_proj (Conv2D) (None, 20, 10, 64)   16448       max_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# inception_3b_1x1_bn (BatchNorma (None, 20, 10, 128)  512         inception_3b_1x1[0][0]
# __________________________________________________________________________________________________
# inception_3b_3x3_bn (BatchNorma (None, 20, 10, 192)  768         inception_3b_3x3[0][0]
# __________________________________________________________________________________________________
# inception_3b_5x5_bn (BatchNorma (None, 20, 10, 96)   384         inception_3b_5x5[0][0]
# __________________________________________________________________________________________________
# inception_3b_pool_proj_bn (Batc (None, 20, 10, 64)   256         inception_3b_pool_proj[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 20, 10, 480)  0           inception_3b_1x1_bn[0][0]
#                                                                  inception_3b_3x3_bn[0][0]
#                                                                  inception_3b_5x5_bn[0][0]
#                                                                  inception_3b_pool_proj_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_18 (MaxPooling2D) (None, 10, 5, 480)   0           concatenate_13[0][0]
# __________________________________________________________________________________________________
# inception_4a_3x3_reduce (Conv2D (None, 10, 5, 96)    46176       max_pooling2d_18[0][0]
# __________________________________________________________________________________________________
# inception_4a5x5_reduce (Conv2D) (None, 10, 5, 16)    7696        max_pooling2d_18[0][0]
# __________________________________________________________________________________________________
# inception_4a_3x3_reduce_bn (Bat (None, 10, 5, 96)    384         inception_4a_3x3_reduce[0][0]
# __________________________________________________________________________________________________
# inception_4a5x5_reduce_bn (Batc (None, 10, 5, 16)    64          inception_4a5x5_reduce[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_19 (MaxPooling2D) (None, 10, 5, 480)   0           max_pooling2d_18[0][0]
# __________________________________________________________________________________________________
# inception_4a_1x1 (Conv2D)       (None, 10, 5, 192)   92352       max_pooling2d_18[0][0]
# __________________________________________________________________________________________________
# inception_4a_3x3 (Conv2D)       (None, 10, 5, 208)   179920      inception_4a_3x3_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_4a_5x5 (Conv2D)       (None, 10, 5, 48)    19248       inception_4a5x5_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_4a_pool_proj (Conv2D) (None, 10, 5, 64)    30784       max_pooling2d_19[0][0]
# __________________________________________________________________________________________________
# inception_4a_1x1_bn (BatchNorma (None, 10, 5, 192)   768         inception_4a_1x1[0][0]
# __________________________________________________________________________________________________
# inception_4a_3x3_bn (BatchNorma (None, 10, 5, 208)   832         inception_4a_3x3[0][0]
# __________________________________________________________________________________________________
# inception_4a_5x5_bn (BatchNorma (None, 10, 5, 48)    192         inception_4a_5x5[0][0]
# __________________________________________________________________________________________________
# inception_4a_pool_proj_bn (Batc (None, 10, 5, 64)    256         inception_4a_pool_proj[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 10, 5, 512)   0           inception_4a_1x1_bn[0][0]
#                                                                  inception_4a_3x3_bn[0][0]
#                                                                  inception_4a_5x5_bn[0][0]
#                                                                  inception_4a_pool_proj_bn[0][0]
# __________________________________________________________________________________________________
# inception_4b_3x3_reduce (Conv2D (None, 10, 5, 112)   57456       concatenate_14[0][0]
# __________________________________________________________________________________________________
# inception_4b5x5_reduce (Conv2D) (None, 10, 5, 24)    12312       concatenate_14[0][0]
# __________________________________________________________________________________________________
# inception_4b_3x3_reduce_bn (Bat (None, 10, 5, 112)   448         inception_4b_3x3_reduce[0][0]
# __________________________________________________________________________________________________
# inception_4b5x5_reduce_bn (Batc (None, 10, 5, 24)    96          inception_4b5x5_reduce[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_20 (MaxPooling2D) (None, 10, 5, 512)   0           concatenate_14[0][0]
# __________________________________________________________________________________________________
# inception_4b_1x1 (Conv2D)       (None, 10, 5, 160)   82080       concatenate_14[0][0]
# __________________________________________________________________________________________________
# inception_4b_3x3 (Conv2D)       (None, 10, 5, 224)   226016      inception_4b_3x3_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_4b_5x5 (Conv2D)       (None, 10, 5, 64)    38464       inception_4b5x5_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_4b_pool_proj (Conv2D) (None, 10, 5, 64)    32832       max_pooling2d_20[0][0]
# __________________________________________________________________________________________________
# inception_4b_1x1_bn (BatchNorma (None, 10, 5, 160)   640         inception_4b_1x1[0][0]
# __________________________________________________________________________________________________
# inception_4b_3x3_bn (BatchNorma (None, 10, 5, 224)   896         inception_4b_3x3[0][0]
# __________________________________________________________________________________________________
# inception_4b_5x5_bn (BatchNorma (None, 10, 5, 64)    256         inception_4b_5x5[0][0]
# __________________________________________________________________________________________________
# inception_4b_pool_proj_bn (Batc (None, 10, 5, 64)    256         inception_4b_pool_proj[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 10, 5, 512)   0           inception_4b_1x1_bn[0][0]
# ...
# inception_4c_pool_proj (Conv2D) (None, 10, 5, 64)    32832       max_pooling2d_21[0][0]
# __________________________________________________________________________________________________
# inception_4c_1x1_bn (BatchNorma (None, 10, 5, 128)   512         inception_4c_1x1[0][0]
# __________________________________________________________________________________________________
# inception_4c_3x3_bn (BatchNorma (None, 10, 5, 256)   1024        inception_4c_3x3[0][0]
# __________________________________________________________________________________________________
# inception_4c_5x5_bn (BatchNorma (None, 10, 5, 64)    256         inception_4c_5x5[0][0]
# __________________________________________________________________________________________________
# inception_4c_pool_proj_bn (Batc (None, 10, 5, 64)    256         inception_4c_pool_proj[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 10, 5, 512)   0           inception_4c_1x1_bn[0][0]
#                                                                  inception_4c_3x3_bn[0][0]
#                                                                  inception_4c_5x5_bn[0][0]
#                                                                  inception_4c_pool_proj_bn[0][0]
# __________________________________________________________________________________________________
# inception_4d_3x3_reduce (Conv2D (None, 10, 5, 144)   73872       concatenate_16[0][0]
# __________________________________________________________________________________________________
# inception_4d5x5_reduce (Conv2D) (None, 10, 5, 32)    16416       concatenate_16[0][0]
# __________________________________________________________________________________________________
# inception_4d_3x3_reduce_bn (Bat (None, 10, 5, 144)   576         inception_4d_3x3_reduce[0][0]
# __________________________________________________________________________________________________
# inception_4d5x5_reduce_bn (Batc (None, 10, 5, 32)    128         inception_4d5x5_reduce[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_22 (MaxPooling2D) (None, 10, 5, 512)   0           concatenate_16[0][0]
# __________________________________________________________________________________________________
# inception_4d_1x1 (Conv2D)       (None, 10, 5, 112)   57456       concatenate_16[0][0]
# __________________________________________________________________________________________________
# inception_4d_3x3 (Conv2D)       (None, 10, 5, 288)   373536      inception_4d_3x3_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_4d_5x5 (Conv2D)       (None, 10, 5, 64)    51264       inception_4d5x5_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_4d_pool_proj (Conv2D) (None, 10, 5, 64)    32832       max_pooling2d_22[0][0]
# __________________________________________________________________________________________________
# inception_4d_1x1_bn (BatchNorma (None, 10, 5, 112)   448         inception_4d_1x1[0][0]
# __________________________________________________________________________________________________
# inception_4d_3x3_bn (BatchNorma (None, 10, 5, 288)   1152        inception_4d_3x3[0][0]
# __________________________________________________________________________________________________
# inception_4d_5x5_bn (BatchNorma (None, 10, 5, 64)    256         inception_4d_5x5[0][0]
# __________________________________________________________________________________________________
# inception_4d_pool_proj_bn (Batc (None, 10, 5, 64)    256         inception_4d_pool_proj[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 10, 5, 528)   0           inception_4d_1x1_bn[0][0]
#                                                                  inception_4d_3x3_bn[0][0]
#                                                                  inception_4d_5x5_bn[0][0]
#                                                                  inception_4d_pool_proj_bn[0][0]
# __________________________________________________________________________________________________
# inception_4e_3x3_reduce (Conv2D (None, 10, 5, 160)   84640       concatenate_17[0][0]
# __________________________________________________________________________________________________
# inception_4e5x5_reduce (Conv2D) (None, 10, 5, 32)    16928       concatenate_17[0][0]
# __________________________________________________________________________________________________
# inception_4e_3x3_reduce_bn (Bat (None, 10, 5, 160)   640         inception_4e_3x3_reduce[0][0]
# __________________________________________________________________________________________________
# inception_4e5x5_reduce_bn (Batc (None, 10, 5, 32)    128         inception_4e5x5_reduce[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_23 (MaxPooling2D) (None, 10, 5, 528)   0           concatenate_17[0][0]
# __________________________________________________________________________________________________
# inception_4e_1x1 (Conv2D)       (None, 10, 5, 256)   135424      concatenate_17[0][0]
# __________________________________________________________________________________________________
# inception_4e_3x3 (Conv2D)       (None, 10, 5, 320)   461120      inception_4e_3x3_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_4e_5x5 (Conv2D)       (None, 10, 5, 128)   102528      inception_4e5x5_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_4e_pool_proj (Conv2D) (None, 10, 5, 128)   67712       max_pooling2d_23[0][0]
# __________________________________________________________________________________________________
# inception_4e_1x1_bn (BatchNorma (None, 10, 5, 256)   1024        inception_4e_1x1[0][0]
# __________________________________________________________________________________________________
# inception_4e_3x3_bn (BatchNorma (None, 10, 5, 320)   1280        inception_4e_3x3[0][0]
# __________________________________________________________________________________________________
# inception_4e_5x5_bn (BatchNorma (None, 10, 5, 128)   512         inception_4e_5x5[0][0]
# __________________________________________________________________________________________________
# inception_4e_pool_proj_bn (Batc (None, 10, 5, 128)   512         inception_4e_pool_proj[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 10, 5, 832)   0           inception_4e_1x1_bn[0][0]
#                                                                  inception_4e_3x3_bn[0][0]
#                                                                  inception_4e_5x5_bn[0][0]
#                                                                  inception_4e_pool_proj_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_24 (MaxPooling2D) (None, 5, 3, 832)    0           concatenate_18[0][0]
# __________________________________________________________________________________________________
# inception_5a_3x3_reduce (Conv2D (None, 5, 3, 160)    133280      max_pooling2d_24[0][0]
# __________________________________________________________________________________________________
# inception_5a5x5_reduce (Conv2D) (None, 5, 3, 32)     26656       max_pooling2d_24[0][0]
# __________________________________________________________________________________________________
# inception_5a_3x3_reduce_bn (Bat (None, 5, 3, 160)    640         inception_5a_3x3_reduce[0][0]
# __________________________________________________________________________________________________
# inception_5a5x5_reduce_bn (Batc (None, 5, 3, 32)     128         inception_5a5x5_reduce[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_25 (MaxPooling2D) (None, 5, 3, 832)    0           max_pooling2d_24[0][0]
# __________________________________________________________________________________________________
# inception_5a_1x1 (Conv2D)       (None, 5, 3, 256)    213248      max_pooling2d_24[0][0]
# __________________________________________________________________________________________________
# inception_5a_3x3 (Conv2D)       (None, 5, 3, 320)    461120      inception_5a_3x3_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_5a_5x5 (Conv2D)       (None, 5, 3, 128)    102528      inception_5a5x5_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_5a_pool_proj (Conv2D) (None, 5, 3, 128)    106624      max_pooling2d_25[0][0]
# __________________________________________________________________________________________________
# inception_5a_1x1_bn (BatchNorma (None, 5, 3, 256)    1024        inception_5a_1x1[0][0]
# __________________________________________________________________________________________________
# inception_5a_3x3_bn (BatchNorma (None, 5, 3, 320)    1280        inception_5a_3x3[0][0]
# __________________________________________________________________________________________________
# inception_5a_5x5_bn (BatchNorma (None, 5, 3, 128)    512         inception_5a_5x5[0][0]
# __________________________________________________________________________________________________
# inception_5a_pool_proj_bn (Batc (None, 5, 3, 128)    512         inception_5a_pool_proj[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 5, 3, 832)    0           inception_5a_1x1_bn[0][0]
#                                                                  inception_5a_3x3_bn[0][0]
#                                                                  inception_5a_5x5_bn[0][0]
#                                                                  inception_5a_pool_proj_bn[0][0]
# __________________________________________________________________________________________________
# inception_5b_3x3_reduce (Conv2D (None, 5, 3, 192)    159936      concatenate_19[0][0]
# __________________________________________________________________________________________________
# inception_5b5x5_reduce (Conv2D) (None, 5, 3, 48)     39984       concatenate_19[0][0]
# __________________________________________________________________________________________________
# inception_5b_3x3_reduce_bn (Bat (None, 5, 3, 192)    768         inception_5b_3x3_reduce[0][0]
# __________________________________________________________________________________________________
# inception_5b5x5_reduce_bn (Batc (None, 5, 3, 48)     192         inception_5b5x5_reduce[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_26 (MaxPooling2D) (None, 5, 3, 832)    0           concatenate_19[0][0]
# __________________________________________________________________________________________________
# inception_5b_1x1 (Conv2D)       (None, 5, 3, 384)    319872      concatenate_19[0][0]
# __________________________________________________________________________________________________
# inception_5b_3x3 (Conv2D)       (None, 5, 3, 384)    663936      inception_5b_3x3_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_5b_5x5 (Conv2D)       (None, 5, 3, 128)    153728      inception_5b5x5_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_5b_pool_proj (Conv2D) (None, 5, 3, 128)    106624      max_pooling2d_26[0][0]
# __________________________________________________________________________________________________
# inception_5b_1x1_bn (BatchNorma (None, 5, 3, 384)    1536        inception_5b_1x1[0][0]
# __________________________________________________________________________________________________
# inception_5b_3x3_bn (BatchNorma (None, 5, 3, 384)    1536        inception_5b_3x3[0][0]
# __________________________________________________________________________________________________
# inception_5b_5x5_bn (BatchNorma (None, 5, 3, 128)    512         inception_5b_5x5[0][0]
# __________________________________________________________________________________________________
# inception_5b_pool_proj_bn (Batc (None, 5, 3, 128)    512         inception_5b_pool_proj[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 5, 3, 1024)   0           inception_5b_1x1_bn[0][0]
#                                                                  inception_5b_3x3_bn[0][0]
#                                                                  inception_5b_5x5_bn[0][0]
#                                                                  inception_5b_pool_proj_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_4 (Glo (None, 1024)         0           concatenate_20[0][0]
# __________________________________________________________________________________________________
# dense_0 (Dense)                 (None, 10)           10250       global_average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 17)           17425       global_average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 21)           21525       global_average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 6)            6150        global_average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 7)            7175        global_average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 61)           0           dense_0[0][0]
#                                                                  dense_1[0][0]
#                                                                  dense_2[0][0]
#                                                                  dense_3[0][0]
#                                                                  dense_4[0][0]
# ==================================================================================================
# Total params: 6,060,781
# Trainable params: 62,525
# Non-trainable params: 5,998,256
# __________________________________________________________________________________________________

# %%
model_gap_low = Model(inputs=model_gh.input, outputs=model_gh.get_layer('conv1_e').output)
model_gap_mid = Model(inputs=model_gh.input, outputs=model_gh.get_layer('conv2_e').output)
model_gap_hig = Model(inputs=model_gh.input, outputs=model_gh.get_layer('conv3_e').output)
#model_gap_hig.summary()
model_gap_part = Model(inputs=model_p.input, outputs=model_p.get_layer('concatenate_20').output)

# %%
cam_low_weights = model_gh.get_layer('low').get_weights()
print(cam_low_weights[0].shape)
cam_mid_weights = model_gh.get_layer('middle').get_weights()
print(cam_mid_weights[0].shape)
cam_hig_weights = model_gh.get_layer('high').get_weights()
print(cam_hig_weights[0].shape)
print("-----------")
cam_head_weights = model_p.get_layer('dense_0').get_weights()
print(cam_head_weights[0].shape)
cam_lowerbody_weights = model_p.get_layer('dense_1').get_weights()
print(cam_lowerbody_weights[0].shape)
cam_upperbody_weights = model_p.get_layer('dense_2').get_weights()
print(cam_upperbody_weights[0].shape)
cam_foot_weights = model_p.get_layer('dense_3').get_weights()
print(cam_foot_weights[0].shape)
cam_global_weights = model_p.get_layer('dense_4').get_weights()
print(cam_global_weights[0].shape)
# Out:
# (512, 4)
# (512, 43)
# (1024, 14)
# -----------
# (1024, 10)
# (1024, 17)
# (1024, 21)
# (1024, 6)
# (1024, 7)

# %%
def load_original(img_path, img_height, img_width):
    # 把原始图片压缩为 299*299大小
    img = image.load_img(img_path, target_size=(image_height, image_width, 3))
    plt.figure(0)
    plt.subplot(211)
    plt.imshow(img)
    return img

img_path = '/home/anhaoran/data/pedestrian_attributes_PETA/PETA/MIT/archive/00044_male_fore.jpg'
img = load_original(img_path, image_height, image_width)
img_arr = image.img_to_array(img)
img_arr = np.expand_dims(img_arr, axis=0)
print(img_arr.shape)

predictions = model_gh.predict(img_arr)
for i in range(len(predictions[0])):
    print(attributes_list[i], ": ", predictions[0, i]>=0.5)
# Out:
# (1, 160, 75, 3)
# upperBodyLogo :  False
# lowerBodyThinStripes :  False
# upperBodyThinStripes :  False
# upperBodyThickStripes :  False
# accessoryHeadphone :  False
# carryingBabyBuggy :  False
# carryingBackpack :  False
# hairBald :  False
# footwearBoots :  False
# carryingOther :  False
# carryingShoppingTro :  False
# carryingUmbrella :  False
# carryingFolder :  False
# accessoryHairBand :  False
# accessoryHat :  False
# lowerBodyHotPants :  False
# upperBodyJacket :  False
# lowerBodyJeans :  False
# accessoryKerchief :  False
# footwearLeatherShoes :  False
# hairLong :  False
# lowerBodyLongSkirt :  False
# upperBodyLongSleeve :  True
# carryingLuggageCase :  False
# carryingMessengerBag :  False
# accessoryMuffler :  False
# accessoryNothing :  True
# carryingNothing :  False
# upperBodyNoSleeve :  False
# carryingPlasticBags :  False
# footwearSandals :  False
# footwearShoes :  True
# hairShort :  True
# lowerBodyShorts :  False
# upperBodyShortSleeve :  False
# lowerBodyShortSkirt :  False
# footwearSneakers :  False
# footwearStocking :  False
# upperBodySuit :  False
# carryingSuitcase :  False
# lowerBodySuits :  False
# accessorySunglasses :  False
# upperBodySweater :  False
# lowerBodyTrousers :  True
# upperBodyTshirt :  False
# upperBodyOther :  True
# upperBodyVNeck :  False
# personalLess15 :  False
# personalLess30 :  True
# personalLess45 :  False
# personalLess60 :  False
# personalLarger60 :  False
# lowerBodyCapri :  False
# lowerBodyCasual :  True
# upperBodyCasual :  True
# personalFemale :  False
# lowerBodyFormal :  False
# upperBodyFormal :  False
# lowerBodyPlaid :  False
# personalMale :  True
# upperBodyPlaid :  False

# %%
feature_map_low = model_gap_low.predict(img_arr)
print(feature_map_low.shape)
feature_map_mid = model_gap_mid.predict(img_arr)
print(feature_map_mid.shape)
feature_map_hig = model_gap_hig.predict(img_arr)
print(feature_map_hig.shape)
feature_map_part = model_gap_part.predict(img_arr)
print(feature_map_part.shape)
# Out:
# (1, 10, 5, 512)
# (1, 10, 5, 512)
# (1, 5, 3, 1024)
# (1, 5, 3, 1024)

# %% [markdown]
# # Low_level attributes

# %%
idx = 1
count = 1
print(attributes_list[idx], ": ", predictions[0, idx])
# Out:
# lowerBodyThinStripes :  5.239796e-26

# %%
from PIL import Image

array_feature_map_low = np.zeros(dtype=np.float32, shape=feature_map_low.shape[1:3])
for i in range(0, 512):
    array_feature_map_low += cam_low_weights[0][i, idx] * feature_map_low[0, :, :, i]#
    
array_feature_map_low -= np.average(array_feature_map_low)
img_feature_map_low = Image.fromarray(array_feature_map_low.astype('uint8'))
img_feature_map_low = img_feature_map_low.resize((image_width, image_height), Image.ANTIALIAS)
#array_feature_map_mid = image.img_to_array(img_feature_map_mid)
#img_feature_map_mid = cv2.applyColorMap(np.uint8(array_feature_map_mid), cv2.COLORMAP_JET)
plt.imshow(img_feature_map_low)

# %%
from sklearn.cluster import KMeans

img_data = np.reshape(np.array(img_feature_map_low), (-1, 1))/256.
print(img_data.shape)
kmeans = KMeans(n_clusters=6, random_state=0).fit(img_data)
#print(kmeans.labels_)
print(kmeans.labels_.shape)
print(kmeans.cluster_centers_)

label = kmeans.labels_.reshape([image_height, image_width])
pic_new = Image.new("L", (image_width, image_height))
min_activation = kmeans.cluster_centers_[kmeans.cluster_centers_.reshape((-1,)).argsort()[-count]][0]
for i in range(image_height):
    for j in range(image_width):
        if kmeans.cluster_centers_[label[i][j]][0] >= min_activation:
            pic_new.putpixel((j, i), 255)
plt.imshow(pic_new)
plt.show()
# Out:
# (12000, 1)
# (12000,)
# [[0.83633067]
#  [0.16799176]
#  [0.96536607]
#  [0.3720126 ]
#  [0.60166912]
#  [0.03075414]]

# %% [markdown]
# # Mid_level attributes

# %%
idx = 46
count = 1
print(attributes_list[idx], ": ", predictions[0, idx])
# Out:
# upperBodyVNeck :  1.3228824e-07

# %%
array_feature_map_mid = np.zeros(dtype=np.float32, shape=feature_map_mid.shape[1:3])
for i in range(0, 512):
    array_feature_map_mid += cam_mid_weights[0][i, idx-4] * feature_map_mid[0, :, :, i]#
    
array_feature_map_mid -= np.average(array_feature_map_mid)
img_feature_map_mid = Image.fromarray(array_feature_map_mid.astype('uint8'))
img_feature_map_mid = img_feature_map_mid.resize((image_width, image_height), Image.ANTIALIAS)
#array_feature_map_mid = image.img_to_array(img_feature_map_mid)
#img_feature_map_mid = cv2.applyColorMap(np.uint8(array_feature_map_mid), cv2.COLORMAP_JET)
plt.imshow(img_feature_map_mid)

# %%
img_data = np.reshape(np.array(img_feature_map_mid), (-1, 1))/256.
print(img_data.shape)
kmeans = KMeans(n_clusters=6, random_state=0).fit(img_data)
#print(kmeans.labels_)
print(kmeans.labels_.shape)
print(kmeans.cluster_centers_)

label = kmeans.labels_.reshape([image_height, image_width])
pic_new = Image.new("L", (image_width, image_height))
min_activation = kmeans.cluster_centers_[kmeans.cluster_centers_.reshape((-1,)).argsort()[-count]][0]
for i in range(image_height):
    for j in range(image_width):
        if kmeans.cluster_centers_[label[i][j]][0] >= min_activation:
            pic_new.putpixel((j, i), 255)
plt.imshow(pic_new)
plt.show()
# Out:
# (12000, 1)
# (12000,)
# [[0.22871514]
#  [0.85859324]
#  [0.04306947]
#  [0.43160585]
#  [0.97915477]
#  [0.64512467]]

# %% [markdown]
# # High_level attributes

# %%
idx = 48
count = 1
print(attributes_list[idx], ": ", predictions[0, idx])
# Out:
# personalLess30 :  0.9025536

# %%
array_feature_map_hig = np.zeros(dtype=np.float32, shape=feature_map_hig.shape[1:3])
for i in range(0, 1024):
    array_feature_map_hig += cam_hig_weights[0][i, idx-48] * feature_map_hig[0, :, :, i]#
    
array_feature_map_hig -= np.average(array_feature_map_hig)
img_feature_map_hig = Image.fromarray(array_feature_map_hig.astype('uint8'))
img_feature_map_hig = img_feature_map_hig.resize((image_width, image_height), Image.ANTIALIAS)
#array_feature_map_mid = image.img_to_array(img_feature_map_mid)
#img_feature_map_mid = cv2.applyColorMap(np.uint8(array_feature_map_mid), cv2.COLORMAP_JET)
plt.imshow(img_feature_map_hig)

# %%
img_data = np.reshape(np.array(img_feature_map_hig), (-1, 1))/256.
print(img_data.shape)
kmeans = KMeans(n_clusters=6, random_state=0).fit(img_data)
#print(kmeans.labels_)
print(kmeans.labels_.shape)
print(kmeans.cluster_centers_)

label = kmeans.labels_.reshape([image_height, image_width])
pic_new = Image.new("L", (image_width, image_height))
min_activation = kmeans.cluster_centers_[kmeans.cluster_centers_.reshape((-1,)).argsort()[-count]][0]
for i in range(image_height):
    for j in range(image_width):
        if kmeans.cluster_centers_[label[i][j]][0] >= min_activation:
            pic_new.putpixel((j, i), 255)
plt.imshow(pic_new)
plt.show()
# Out:
# (12000, 1)
# (12000,)
# [[0.582355  ]
#  [0.02138666]
#  [0.9851919 ]
#  [0.38204606]
#  [0.78929228]
#  [0.192958  ]]
